# %%
import torch, platform
print("CUDA available?", torch.cuda.is_available())
if torch.cuda.is_available():
    print("Device:", torch.cuda.get_device_name(0))
# Out:
# CUDA available? True
# Device: NVIDIA A2

# %%
device = (
    torch.device('cuda') if torch.cuda.is_available()
    else torch.device('mps') if hasattr(torch.backends, "mps") and torch.backends.mps.is_available()
    else torch.device('cpu')
)
print("Using device:", device)
# Out:
# Using device: cuda

# %%
# from google.colab import files
# uploaded = files.upload()        # choose heatEquation_data.mat

# %%
# !pip install pyDOE
# Out:
# Requirement already satisfied: pyDOE in /mnt/scratch/pmfz/MyEnv/pt1/lib/python3.11/site-packages (0.3.8)
# Requirement already satisfied: numpy in /mnt/scratch/pmfz/MyEnv/pt1/lib/python3.11/site-packages (from pyDOE) (1.26.4)
# Requirement already satisfied: scipy in /mnt/scratch/pmfz/MyEnv/pt1/lib/python3.11/site-packages (from pyDOE) (1.16.1)

# %%
# For readability: disable warnings
import warnings
warnings.filterwarnings('ignore')
import os
# import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
import scipy.io
from scipy.interpolate import griddata
import time
from itertools import product, combinations
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d.art3d import Poly3DCollection
from mpl_toolkits.axes_grid1 import make_axes_locatable
import matplotlib.gridspec as gridspec
import scipy.sparse as sp
import scipy.sparse.linalg as la
from pyDOE import lhs
from matplotlib.colors import LogNorm
from matplotlib.ticker import LogLocator, FuncFormatter
from matplotlib.ticker import FormatStrFormatter
import copy

# %% [markdown]
# <hr>
#
# # Reconstructing the entire solution to the 1D heat equation using Neural Networks
#
# <div style="padding: 10px;">
#
# **Model Problem: 1D Heat Equation**
#
# We begin by describing the first model problem - the one-dimensional heat equation.
#
# The heat equation is the prototypical parabolic partial differential equation and can be applied to modelling the diffusion of heat through a given region. Read more about the heat equation here: [https://en.wikipedia.org/wiki/Heat_equation](https://en.wikipedia.org/wiki/Heat_equation).
#
# In 1D, the heat equation can be written as:
#
# \begin{equation}
# \frac{\partial u}{\partial t} = k \frac{\partial^2 u}{\partial x^2 },
# \end{equation}
#
# where $k$ is a material parameter called the coefficient of thermal diffusivity.
#
# This equation can be solved using numerical methods, such as finite differences or finite elements. For this notebook, we will solve for $u(x,t)$ the above equation numerically on a domain of $x \in [0,1]$ and $t \in [0, 0.25]$.
#
# The procedure in this notebook is the following:
# - read in a dataset that describes an exact solution to the heat equation. This is treated as the benchmark to which any reconstruction is compared.
# - downsample the dataset to get a sparse collection of "measurements".
# - Using this sparse dataset, with knowledge of the physics, attempt to reconstruct the entire solution.
# - Evaluating this solution at $t=0$ gives the initial profile, thus solving the inverse problem of finding the initial state.
# </div>

# %%
# data = scipy.io.loadmat('/content/heatEquation_data.mat')

# %% [markdown]
# <div style="padding: 10px;">
#
# # Configuring the network
#
# A feedforward neural network of the following structure is assumed:
# - the input layer (with two inputs: $x$ and $t$) takes 2D data $(x,t)$ scaled elementwise to lie in the interval $[-1, 1]^2$,
# - this is followed by 8 fully connected layers each containing 20 neurons and each using a hyperbolic tangent activation function,
# - one fully connected output layer with a single neuron.
#
# We can count up the number of unknowns:
#
# - The first fully connected layer has 20 neurons, each of which has two inputs and one bias term, a total of $20 \cdot 3 = 60$ unknowns.
# - The remaining 7 fully connected layers each have 20 neurons with 20 inputs and a bias term, a total of $7 \cdot 20 \cdot 21=2940$ unknowns.
# - The final output layer has 1 neuron with 20 inputs and one bias, a total of 21 unknowns.
#
# Overall, the network has 3021 unknown weights and bias terms.
#
#
# </div>

# %%
# structure of network: two inputs (x,t) and one output u
# 8 fully connected layers with 20 nodes per layer
layers = [2, 50, 50, 50, 1]

# %% [markdown]
#  <div style="padding: 10px;">
#
# # Sampling of data and collocation
#
# We make the choices of:
# - `N_u` (e.g. 100) data points that will constrain the network
# - `N_f` collocation points (e.g. 3000) to implement the physics-informed constraint.
# - `k=1` as the coefficient of diffusivity
#
# Once you have run through the notebook once you may wish to alter any of the sampling or network configuration parameters.
#
# Note that in this example we have more constraints on the network (3100) than free parameters (3021), but this will change depending on network configuration.
# </div>

# %%
k = 1
N_i = 101
N_b = 51
N_u = N_i + 2 * N_b  # number of data points
N_f = 3000           # Collocation points
N_val = 100         # Validation points

# %% [markdown]
# <hr>
# <div style="padding: 10px;">
#
# ###  Reformat input data
#
# The data comes from a file, containing lists of x and t and the solution on the associated grid.
# Unfortunately we need it in a different format!
#
# Variables that are defined here:
#
# `Exact` - this is the solution read in from the file. It is the benchmark to which we will compare any reconstruction.
#
# `X_star` - a vector of (x,t) coordinate pairs. This contains the boundary points (note this for later!)
#
# `u_star` - the associated solution (a reformatted version of `Exact`)
#
# `lb`: Vector containing the lower bound of all of the coordinate variables, e.g. $x_{min}$, $t_{min}$.
#
# `ub`: Vector containing the upper bound of all of the coordinate variables, e.g. $x_{max}$, $t_{max}$.
#
#
# </div>

# %%
# t = data['t'].flatten()[:,None] # read in t and flatten into column vector
# x = data['x'].flatten()[:,None] # read in x and flatten into column vector
#  # Exact represents the exact solution to the problem, from the data provided
# Exact = np.real(data['usol']).T # Exact has structure of nt times nx

# print("usol shape (nt, nx) = ", Exact.shape)

# # We need to find all the x,t coordinate pairs in the domain
# X, T = np.meshgrid(x,t)

# # Flatten the coordinate grid into pairs of x,t coordinates
# X_star = np.hstack((X.flatten()[:,None], T.flatten()[:,None])) # coordinates x,t
# u_star = Exact.flatten()[:,None]   # corresponding solution value with each coordinate


# print("X has shape ", X.shape, ", X_star has shape ", X_star.shape, ", u_star has shape ", u_star.shape)

# # Domain bounds (-1,1)
# lb = X_star.min(axis=0)
# ub = X_star.max(axis=0)

# print("Lower bounds of x,t: ", lb)
# print("Upper bounds of x,t: ", ub)
# print('')
# print('The first few entries of X_star are:')
# print( X_star[0:5, :] )

# print('')
# print('The first few entries of u_star are:')
# print( u_star[0:5, :] )

# %% [markdown]
# <div style="padding: 10px;">
#
# ## Select collocation points
#
# We now randomly select the `N_f` collocation points for the physics constraints. We do this using Latin Hypercube Sampling
# https://en.wikipedia.org/wiki/Latin_hypercube_sampling
#
# producing:
# -  `X_f_train` the coordinates of the collocation set
#
# ## Select data points
#
# Randomly select `N_u` points from the original dataset, producing:
# -  `X_u_train` the coordinates of the training set
# -  `u_train` the corresponding value of the solution value.
#
# </div>

# %%
## train using internal points
#X_u_train = X_star
#u_train = u_star

## Generate collocation points using Latin Hypercube sampling within the bounds of the spatio-temporal coordinates
# Generate N_f x,t coordinates within range of upper and lower bounds
# 1) Bounds (x_min, t_min) and (x_max, t_max)
lb = np.array([0.0, 0.0], dtype=np.float32)
ub = np.array([1.0, 0.25], dtype=np.float32)
np.random.seed(123)
U_all = lhs(2, samples=N_f + N_val)            # in [0,1]^2
X_all = lb + (ub - lb) * U_all                  # map to [lb, ub]
X_f_train = X_all[:N_f]                         # 3000 collocation
X_val    = X_all[N_f:]                         # 100 validation (disjoint)

## In addition, we add the X_u_train co-ordinates from the boundaries to the X_f coordinate set
#X_f_train = np.vstack((X_f_train, X_u_train)) # stack up all training x,t coordinates for u and f


# Generate training data
# Domain boundaries
x_min, x_max = 0.0, 1.0
t_min, t_max = 0.0, 0.25

# --- Initial condition: u(x,0) = sin(pi x) ---
x_ic = np.linspace(x_min, x_max, N_i)
t_ic = np.zeros_like(x_ic)
u_ic = np.sin(np.pi * x_ic)

# --- Boundary conditions: u(0,t) = 0, u(1,t) = 0 (example Dirichlet) ---
t_line = np.linspace(t_min, t_max, N_b)
x_bc_left  = np.full(N_b, x_min)
x_bc_right = np.full(N_b, x_max)
u_bc_left  = np.zeros(N_b)
u_bc_right = np.zeros(N_b)

# --- Stack IC and BC *row-wise* (NO meshgrid here) ---
x_u = np.concatenate([x_ic,       x_bc_left,   x_bc_right])[:, None]   # (N_i+2N_b, 1)
t_u = np.concatenate([t_ic,       t_line,      t_line     ])[:, None]  # (N_i+2N_b, 1)
u   = np.concatenate([u_ic,       u_bc_left,   u_bc_right ])[:, None]  # (N_i+2N_b, 1)

X_u_train = np.hstack([x_u, t_u])   # shape (N_u, 2)  with columns [x, t]
u_train   = u                       # shape (N_u, 1)

print('')
print('The first few entries of X_u_train are:')
print( X_u_train[0:5] )

print('')
print('The first few entries of u_train are:')
print( u_train[0:5] )

print('')
print("Shapes of X_f_train and X_val are:")
print(f"X_f_train: {X_f_train.shape},  X_val: {X_val.shape}")
# Out:
# The first few entries of X_u_train are:
# [[0.   0.  ]
#  [0.01 0.  ]
#  [0.02 0.  ]
#  [0.03 0.  ]
#  [0.04 0.  ]]
#
# The first few entries of u_train are:
# [[0.        ]
#  [0.03141076]
#  [0.06279052]
#  [0.09410831]
#  [0.12533323]]
#
# Shapes of X_f_train and X_val are:
# X_f_train: (3000, 2),  X_val: (100, 2)

# %%
## Make a plot to show the distribution of training data
plt.scatter(X_f_train[:,0], X_f_train[:,1], marker='x', color='red',alpha=0.8)
plt.scatter(X_val[:,0],     X_val[:,1],     marker='x', color='green',alpha=0.8)
plt.scatter(X_u_train[:,0], X_u_train[:,1], marker='x', color='black')
plt.xlabel('x')
plt.ylabel('t')
plt.title('Data points and collocation points')
plt.legend(['Collocation Points', 'Validation Points', 'Data Points'])
plt.show()

# %% [markdown]
# <hr>
# <div style="padding: 10px;">
#
# ## Encoding of the network and physics constraint
# The function **$u(x,t)$** that we seek is defined below as the function `net_u`; the physics constraint **$f(x,t)$** is defined in the function `net_f`
#
#
# 1. we read in the value of k first so that it can be included in the equations
# 2. then we evaluate u for the X_f input coordinates (collocation points)
# 3. then we use pytorch differentiation (autograd) to calculate the derivatives of the solution
# 4. finally we encode the PDE in residual form, as f->0, u_t = k*u_xx, which is the governing equation
#
# </div>

# %%
def u_true_numpy(X, T):
    """Vectorised true solution: U = exp(-(pi^2) * T) * sin(pi * X)."""
    return np.exp(-(np.pi**2) * T) * np.sin(np.pi * X)

# %%
def net_u(x, t, model):
    X = torch.cat([x, t], dim=1)  # If x and t are each shape (N, 1), then X becomes (N, 2).
    u = model(X)
    return u

def net_f(x, t, model):
    x.requires_grad_(True)
    t.requires_grad_(True)
    u = net_u(x, t, model)
    u_x = torch.autograd.grad(u, x, grad_outputs=torch.ones_like(u), create_graph=True, retain_graph=True)[0]
    u_t = torch.autograd.grad(u, t, grad_outputs=torch.ones_like(u), create_graph=True, retain_graph=True)[0]
    u_xx = torch.autograd.grad(u_x, x, grad_outputs=torch.ones_like(u_x), create_graph=True)[0]
    f = u_t - model.k * u_xx
    return f

# %% [markdown]
# # PyTorch module class and initialization
#
# <div style="padding: 10px;">
#
# This code sets up a Physics-Informed Neural Network (PINN) for solving the 1D heat equation using PyTorch. Here's a summary of the key components:
#
# 1. `XavierInit` Class:
#
# Custom layer initialization using Xavier initialization (https://365datascience.com/tutorials/machine-learning-tutorials/what-is-xavier-initialization/), which is designed to keep the scale of the gradients roughly the same in all layers.
# Initializes weights and biases for a layer.
#
# 2. `initialize_NN` Function:
#
# Creates a list of layers using the XavierInit class.
# Takes a list of layer sizes and initializes each layer accordingly.
#
# 3. `NeuralNet()` constructs the network where the input and output coordinates are normalised so that all values lie between -1 and 1; this improves training. Applies the layers sequentially with the tanh activation function, except for the last layer.
#
#
# Using the PyTorch module classes allow you to create more complex models controlling exactly how the data flows through the model [overview of PyTorch Modules here](https://www.learnpytorch.io/02_pytorch_classification/)
#
# </div>

# %%
class XavierInit(nn.Module):
    def __init__(self, size):
        super(XavierInit, self).__init__()
        in_dim = size[0]
        out_dim = size[1]
        xavier_stddev = torch.sqrt(torch.tensor(2.0 / (in_dim + out_dim)))
        self.weight = nn.Parameter(torch.randn(in_dim, out_dim) * xavier_stddev)
        self.bias = nn.Parameter(torch.zeros(out_dim))

    def forward(self, x):
        return torch.matmul(x, self.weight) + self.bias      # why define this ?????????

def initialize_NN(layers):
    weights = nn.ModuleList()
    num_layers = len(layers)
    for l in range(num_layers - 1):
        layer = XavierInit(size=[layers[l], layers[l + 1]]) # if there was no retutn, how do I get the weight and bias?
        weights.append(layer)
    return weights

class NeuralNet(nn.Module):
    def __init__(self, layers, lb, ub,k_init):
        super(NeuralNet, self).__init__()
        self.weights = initialize_NN(layers)
        # make lb/ub move with .to(device)
        self.register_buffer('lb', torch.as_tensor(lb, dtype=torch.float32))     # <<< CHANGED >>>
        self.register_buffer('ub', torch.as_tensor(ub, dtype=torch.float32))     # <<< CHANGED >>>
        self.register_buffer('k', torch.tensor(k_init, dtype=torch.float32))     # <<< CHANGED >>>


    def forward(self, X):
        X = X.float()                                                            # <<< CHANGED >>>
        lb = self.lb.to(X.device)                                                # <<< CHANGED >>>
        ub = self.ub.to(X.device)                                                # <<< CHANGED >>>
        H = 2.0 * (X - self.lb) / (self.ub - self.lb) - 1.0
        for l in range(len(self.weights) - 1):
            H = torch.tanh(self.weights[l](H.float()))     # Is this already a calculation?
        Y = self.weights[-1](H)
        return Y

# %%
l = XavierInit(size = [2, 3]) 
print(f"{l}")
print("weight shape:", l.weight.shape)
print("bias shape:", l.bias.shape)
print("weight:\n", l.weight)     # full tensor
print("bias:\n", l.bias)
# Out:
# XavierInit()
# weight shape: torch.Size([2, 3])
# bias shape: torch.Size([3])
# weight:
#  Parameter containing:
# tensor([[ 0.5545, -0.6726,  0.5623],
#         [-1.3916,  0.2910, -0.5361]], requires_grad=True)
# bias:
#  Parameter containing:
# tensor([0., 0., 0.], requires_grad=True)

# %% [markdown]
# <div style="padding: 10px;">
#
# ### Note about Tensors in PyTorch
#
# In PyTorch, tensors are the primary data structure used for storing and manipulating data. Below is an expanded explanation of setting up tensors, including requiring gradients and setting data types.
#
# **Requiring Gradients**:
# - To enable automatic differentiation, set `requires_grad=True` when creating a tensor. This allows PyTorch to track operations on the tensor and compute gradients during backpropagation.
#
# **Data Types**:
#   - PyTorch supports various data types, such as `float32`, `float64`, `int32`, `int64`, etc.
#   - The data type can be specified using the `dtype` argument when creating a tensor, as your data types must match when performing operations
#
#
# </div>

# %% [markdown]
# <div style="padding: 10px;">
#
# ## Training
#
# 1. Initialize Loss Function and Optimizer:
#
# * criterion = `nn.MSELoss()`
# * optimizer = `torch.optim.Adam(model.parameters(), lr=learning_rate)`
#
# 2. Prepare Input Data:
#
# Extract `x` and `t` from `X`. Convert `x`, `t`, and `u` to PyTorch tensors with `requires_grad=True`.
#
#
# 3. Training Loop:
#
# * Loop over the number of iterations (nIter).
# * Zero the gradients: optimizer.zero_grad().
# * Predict u and the residual f using the model: u_pred and f_pred.
# * Compute the loss:
#     * `loss_PDE`: Mean Squared Error (MSE) between `f_pred` and zero.
#     * `loss_data`: MSE between `u_tf` and `u_pred`.
#     * Total loss: loss = loss_PDE + 5*loss_data.
# * Backpropagate the loss: `loss.backward()`.
# * Update the model parameters: `optimizer.step()`.
#
# 4. Print Progress:
#
# Every 500 iterations, print the current iteration, loss, and elapsed time.
#
# </div>

# %%
def train(nEpoch, X, u, X_f, X_val, model, learning_rate):
    criterion = nn.MSELoss()
    
    # ----- STAGE 1: start with Adam -----
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    
    # when to switch from Adam to L-BFGS
    switch_epoch = 50000
    used_lbfgs   = False   
    lbfgs_epochs   = 100           # <-- how many epochs of L-BFGS you want
    lbfgs_start_ep = None          # <-- will store the epoch where we switch

    # use the model's device
    dev = next(model.parameters()).device                                        # <<< CHANGED >>>
    
    x = X[:,0:1]
    t = X[:,1:2]
    # Collocation points (f points)
    x_f = X_f[:, 0:1]
    t_f = X_f[:, 1:2]
    x_v = X_val[:, 0:1]
    t_v = X_val[:, 1:2]
    
    u_v_true = u_true_numpy(x_v, t_v)   # shape (N_val,)

    # create tensors ON THE SAME DEVICE
    x_tf      = torch.tensor(x,   dtype=torch.float32, device=dev, requires_grad=True)   # <<< CHANGED >>>
    t_tf      = torch.tensor(t,   dtype=torch.float32, device=dev, requires_grad=True)   # <<< CHANGED >>>
    u_tf      = torch.tensor(u,   dtype=torch.float32, device=dev)                       # <<< CHANGED >>>
    x_f_tf    = torch.tensor(x_f, dtype=torch.float32, device=dev, requires_grad=True)   # <<< CHANGED >>>
    t_f_tf    = torch.tensor(t_f, dtype=torch.float32, device=dev, requires_grad=True)   # <<< CHANGED >>>
    x_v_tf    = torch.tensor(x_v, dtype=torch.float32, device=dev)
    t_v_tf    = torch.tensor(t_v, dtype=torch.float32, device=dev)
    u_true_tf = torch.tensor(u_v_true, dtype=torch.float32, device=dev).reshape(-1, 1)

    mse_v_hist = []
    loss_values = []

    patience   = 100000
    pat        = 0
    best_v     = float('inf')
    best_state = copy.deepcopy(model.state_dict())
    best_ep    = -1  
    best_TL    = float('inf')

    start_time  = time.time()
    total_start = time.time()        # total wall-clock timer
    
    for ep in range(nEpoch):

        # ----- Stop if we've done lbfgs_epochs of L-BFGS -----
        if used_lbfgs and lbfgs_start_ep is not None:
            if ep - lbfgs_start_ep >= lbfgs_epochs:
                print(f"Stopping after {lbfgs_epochs} LBFGS epochs at global epoch {ep}")
                break

        # ------------------------------
        # STAGE 1: Adam (ep < switch_epoch)
        # STAGE 2: L-BFGS (ep >= switch_epoch)
        # ------------------------------
        if ep < switch_epoch:
            # ----- Adam update -----
            optimizer.zero_grad()
            
            # Compute predictions for training data (u)
            u_pred = net_u(x_tf, t_tf, model)
            # Compute PDE residual at collocation points
            u_f_pred = net_f(x_f_tf, t_f_tf, model)
    
            loss_PDE  = criterion(u_f_pred, torch.zeros_like(u_f_pred))
            loss_data = criterion(u_tf, u_pred)
            loss = loss_PDE + 100 * loss_data
    
            loss.backward()
            optimizer.step()
            
        else:
            # ----- Switch to L-BFGS once -----
            if not used_lbfgs:
                # 1) Load the best Adam weights BEFORE creating LBFGS
                model.load_state_dict(best_state)
        
                # 2) Print which Adam state you're starting from
                print(
                    f"Switching to L-BFGS at epoch {ep} "
                    f"-> starting from Adam best at epoch {best_ep} "
                    f"(TrainLoss={best_TL:.3e}, Val MSE={best_v:.3e})"
                )
        
                # 3) Create the LBFGS optimiser on top of that state
                optimizer = torch.optim.LBFGS(
                    model.parameters(),
                    max_iter=20,          # internal LBFGS iterations per .step()
                    history_size=100,
                    line_search_fn=None
                )
                used_lbfgs = True
                lbfgs_start_ep = ep      # <-- remember when we switched
                

            # L-BFGS requires a closure that re-computes the loss
            def closure():
                optimizer.zero_grad()
                u_pred   = net_u(x_tf, t_tf, model)
                u_f_pred = net_f(x_f_tf, t_f_tf, model)

                loss_PDE  = criterion(u_f_pred, torch.zeros_like(u_f_pred))
                loss_data = criterion(u_tf, u_pred)
                loss      = loss_PDE + 100 * loss_data

                loss.backward()
                return loss

            loss = optimizer.step(closure)  # returns the loss from the last closure call

        
        # ----- validation -----
        model.eval()
        with torch.no_grad():
            u_v_pred = net_u(x_v_tf, t_v_tf, model)
            mse_v = criterion(u_v_pred, u_true_tf).item()
            mse_v_hist.append((ep, mse_v))

        model.train()  # switch back


        # ----- early stopping on val -----
        # if mse_v < best_v:
        if loss.item() < best_TL:
            best_v     = mse_v
            best_state = copy.deepcopy(model.state_dict())
            best_ep    = ep
            best_TL    = loss.item()
            # print(f"[Improved] Epoch {ep} | Best Val MSE: {best_v:.3e}")
            pat = 0
        else:
            pat += 1
            if pat >= patience:
                print(f"Early stopping at it={ep}, best Val MSE={best_v:.3e}")
                break
        
        # Print progress
        # - Before LBFGS: every 1000 epochs
        # - After LBFGS is enabled: every 100 epochs
        if (not used_lbfgs and ep % 100 == 0) or (used_lbfgs and ep % 10 == 0):
            elapsed = time.time() - start_time
            print(f"Epochs: {ep:6d} | TrainLoss: {loss.item():.3e} "
                  f"| Val MSE: {mse_v:.3e} "
                  f"| Time: {elapsed:.2f}s")
            start_time = time.time()
            
        loss_values.append(loss.item())
        
    total_elapsed = time.time() - total_start
    print(f"Total training time: {total_elapsed:.2f} s")
    print(f"Best Val MSE: {best_v:.3e} at epoch {best_ep} (TLoss: {best_TL:.3e})") 

    model.load_state_dict(best_state)          # <- load best here

    return loss_values, mse_v_hist, best_ep, best_v

# %% [markdown]
# <div style="padding: 10px;">
#
# ## Finally, you can train the model!
#
# Training might take a while depending on the value of `Train_iterations` and also the specification of the machine you are running on.
# If you set Train_iterations too low the end results will be unconverged. A value of 20000 was used to achieve excellent results.
#
# Other are available in PyTorch, see [PyTorch Optimizers](https://pytorch.org/docs/stable/optim.html) for more information.

# %%
#initialise model
model = NeuralNet(layers, lb, ub,k).to(device).float()

# Training
Train_epochs=100000
learning_rate=0.0005

# training data
x = X_u_train[:,0:1]
t = X_u_train[:,1:2]

# collocation
x_f_train = X_f_train[:, 0:1]  # x values of the collocation points
t_f_train = X_f_train[:, 1:2]  # t values of the collocation points

# Convert to tensors and ensure they require gradients
x_f_t = torch.tensor(x_f_train, dtype=torch.float32, device=device, requires_grad=True)  # <<< CHANGED >>>
t_f_t = torch.tensor(t_f_train, dtype=torch.float32, device=device, requires_grad=True)  # <<< CHANGED >>>

x_tf = torch.tensor(x,       dtype=torch.float32, device=device, requires_grad=True)     # <<< CHANGED >>>
t_tf = torch.tensor(t,       dtype=torch.float32, device=device, requires_grad=True)     # <<< CHANGED >>>
u_tf = torch.tensor(u_train, dtype=torch.float32, device=device, requires_grad=True)     # <<< CHANGED >>>

model = model.float()
x_tf = x_tf.float()
t_tf = t_tf.float()
u_tf = u_tf.float()

loss_values, mse_v_hist, best_ep, best_v = train(Train_epochs, X_u_train, u_train, X_f_train, X_val, model, learning_rate)
print(f"[Summary] Best Val MSE {best_v:.3e} at epoch {best_ep}")
# Out:
# Epochs:      0 | TrainLoss: 3.439e+01 | Val MSE: 1.091e-01 | Time: 4.41s
# Epochs:    100 | TrainLoss: 7.717e+00 | Val MSE: 1.516e-02 | Time: 0.36s
# Epochs:    200 | TrainLoss: 3.462e+00 | Val MSE: 4.835e-03 | Time: 0.33s
# Epochs:    300 | TrainLoss: 2.003e+00 | Val MSE: 2.221e-03 | Time: 0.33s
# Epochs:    400 | TrainLoss: 1.222e+00 | Val MSE: 1.582e-03 | Time: 0.33s
# Epochs:    500 | TrainLoss: 6.278e-01 | Val MSE: 8.103e-04 | Time: 0.33s
# Epochs:    600 | TrainLoss: 3.302e-01 | Val MSE: 4.010e-04 | Time: 0.33s
# Epochs:    700 | TrainLoss: 1.952e-01 | Val MSE: 2.734e-04 | Time: 0.33s
# Epochs:    800 | TrainLoss: 1.269e-01 | Val MSE: 1.948e-04 | Time: 0.33s
# Epochs:    900 | TrainLoss: 8.728e-02 | Val MSE: 1.308e-04 | Time: 0.33s
# Epochs:   1000 | TrainLoss: 5.867e-02 | Val MSE: 8.189e-05 | Time: 0.33s
# Epochs:   1100 | TrainLoss: 3.650e-02 | Val MSE: 4.337e-05 | Time: 0.33s
# Epochs:   1200 | TrainLoss: 2.096e-02 | Val MSE: 2.019e-05 | Time: 0.33s
# Epochs:   1300 | TrainLoss: 1.430e-02 | Val MSE: 1.432e-05 | Time: 0.33s
# Epochs:   1400 | TrainLoss: 1.027e-02 | Val MSE: 1.058e-05 | Time: 0.32s
# Epochs:   1500 | TrainLoss: 7.652e-03 | Val MSE: 7.599e-06 | Time: 0.33s
# Epochs:   1600 | TrainLoss: 5.906e-03 | Val MSE: 6.255e-06 | Time: 0.31s
# Epochs:   1700 | TrainLoss: 4.716e-03 | Val MSE: 5.197e-06 | Time: 0.33s
# Epochs:   1800 | TrainLoss: 3.913e-03 | Val MSE: 4.655e-06 | Time: 0.31s
# Epochs:   1900 | TrainLoss: 3.342e-03 | Val MSE: 4.047e-06 | Time: 0.33s
# Epochs:   2000 | TrainLoss: 2.958e-03 | Val MSE: 3.925e-06 | Time: 0.31s
# Epochs:   2100 | TrainLoss: 2.635e-03 | Val MSE: 3.313e-06 | Time: 0.33s
# Epochs:   2200 | TrainLoss: 3.316e-03 | Val MSE: 4.582e-06 | Time: 0.32s
# Epochs:   2300 | TrainLoss: 2.223e-03 | Val MSE: 2.744e-06 | Time: 0.31s
# Epochs:   2400 | TrainLoss: 2.079e-03 | Val MSE: 2.631e-06 | Time: 0.31s
# Epochs:   2500 | TrainLoss: 1.954e-03 | Val MSE: 2.234e-06 | Time: 0.30s
# Epochs:   2600 | TrainLoss: 2.054e-03 | Val MSE: 2.733e-06 | Time: 0.31s
# Epochs:   2700 | TrainLoss: 1.775e-03 | Val MSE: 2.055e-06 | Time: 0.30s
# Epochs:   2800 | TrainLoss: 1.717e-03 | Val MSE: 1.771e-06 | Time: 0.30s
# Epochs:   2900 | TrainLoss: 6.076e-03 | Val MSE: 1.627e-05 | Time: 0.31s
# Epochs:   3000 | TrainLoss: 4.215e-03 | Val MSE: 1.199e-05 | Time: 0.30s
# Epochs:   3100 | TrainLoss: 1.471e-03 | Val MSE: 1.463e-06 | Time: 0.31s
# Epochs:   3200 | TrainLoss: 4.569e-03 | Val MSE: 3.610e-05 | Time: 0.32s
# Epochs:   3300 | TrainLoss: 1.360e-03 | Val MSE: 1.297e-06 | Time: 0.30s
# Epochs:   3400 | TrainLoss: 1.322e-03 | Val MSE: 1.115e-06 | Time: 0.30s
# Epochs:   3500 | TrainLoss: 1.264e-03 | Val MSE: 1.123e-06 | Time: 0.32s
# Epochs:   3600 | TrainLoss: 1.484e-03 | Val MSE: 1.369e-06 | Time: 0.31s
# Epochs:   3700 | TrainLoss: 1.178e-03 | Val MSE: 9.918e-07 | Time: 0.31s
# Epochs:   3800 | TrainLoss: 1.151e-03 | Val MSE: 1.024e-06 | Time: 0.30s
# Epochs:   3900 | TrainLoss: 1.871e-03 | Val MSE: 3.067e-06 | Time: 0.32s
# Epochs:   4000 | TrainLoss: 1.064e-03 | Val MSE: 8.223e-07 | Time: 0.35s
# Epochs:   4100 | TrainLoss: 1.956e-03 | Val MSE: 1.942e-06 | Time: 0.35s
# Epochs:   4200 | TrainLoss: 9.967e-04 | Val MSE: 7.980e-07 | Time: 0.34s
# Epochs:   4300 | TrainLoss: 9.661e-04 | Val MSE: 7.759e-07 | Time: 0.33s
# Epochs:   4400 | TrainLoss: 3.780e-03 | Val MSE: 1.846e-05 | Time: 0.35s
# Epochs:   4500 | TrainLoss: 9.037e-04 | Val MSE: 6.530e-07 | Time: 0.30s
# Epochs:   4600 | TrainLoss: 8.938e-04 | Val MSE: 6.873e-07 | Time: 0.30s
# Epochs:   4700 | TrainLoss: 8.616e-04 | Val MSE: 7.515e-07 | Time: 0.29s
# Epochs:   4800 | TrainLoss: 5.924e-03 | Val MSE: 4.033e-05 | Time: 0.31s
# Epochs:   4900 | TrainLoss: 1.131e-02 | Val MSE: 4.172e-05 | Time: 0.29s
# Epochs:   5000 | TrainLoss: 7.692e-04 | Val MSE: 4.831e-07 | Time: 0.30s
# Epochs:   5100 | TrainLoss: 7.855e-04 | Val MSE: 4.130e-07 | Time: 0.30s
# Epochs:   5200 | TrainLoss: 7.742e-04 | Val MSE: 5.004e-07 | Time: 0.30s
# Epochs:   5300 | TrainLoss: 8.414e-03 | Val MSE: 3.555e-05 | Time: 0.30s
# Epochs:   5400 | TrainLoss: 6.795e-04 | Val MSE: 3.893e-07 | Time: 0.30s
# Epochs:   5500 | TrainLoss: 3.117e-03 | Val MSE: 2.713e-05 | Time: 0.32s
# Epochs:   5600 | TrainLoss: 5.915e-03 | Val MSE: 2.845e-05 | Time: 0.30s
# Epochs:   5700 | TrainLoss: 6.182e-04 | Val MSE: 3.152e-07 | Time: 0.30s
# Epochs:   5800 | TrainLoss: 8.549e-04 | Val MSE: 1.820e-06 | Time: 0.31s
# Epochs:   5900 | TrainLoss: 2.635e-03 | Val MSE: 5.787e-07 | Time: 0.30s
# Epochs:   6000 | TrainLoss: 6.378e-04 | Val MSE: 3.921e-07 | Time: 0.30s
# Epochs:   6100 | TrainLoss: 5.470e-04 | Val MSE: 2.781e-07 | Time: 0.30s
# Epochs:   6200 | TrainLoss: 3.773e-03 | Val MSE: 7.551e-06 | Time: 0.31s
# Epochs:   6300 | TrainLoss: 5.179e-04 | Val MSE: 2.643e-07 | Time: 0.30s
# Epochs:   6400 | TrainLoss: 7.859e-03 | Val MSE: 1.897e-05 | Time: 0.29s
# Epochs:   6500 | TrainLoss: 4.835e-04 | Val MSE: 2.363e-07 | Time: 0.30s
# Epochs:   6600 | TrainLoss: 4.828e-04 | Val MSE: 2.494e-07 | Time: 0.30s
# Epochs:   6700 | TrainLoss: 4.682e-04 | Val MSE: 3.399e-07 | Time: 0.32s
# Epochs:   6800 | TrainLoss: 4.427e-04 | Val MSE: 1.980e-07 | Time: 0.30s
# Epochs:   6900 | TrainLoss: 4.386e-04 | Val MSE: 1.663e-07 | Time: 0.29s
# Epochs:   7000 | TrainLoss: 4.228e-04 | Val MSE: 3.176e-07 | Time: 0.32s
# Epochs:   7100 | TrainLoss: 4.124e-04 | Val MSE: 2.343e-07 | Time: 0.29s
# Epochs:   7200 | TrainLoss: 6.884e-04 | Val MSE: 1.251e-06 | Time: 0.30s
# Epochs:   7300 | TrainLoss: 4.808e-04 | Val MSE: 3.074e-07 | Time: 0.29s
# Epochs:   7400 | TrainLoss: 4.555e-04 | Val MSE: 6.339e-07 | Time: 0.29s
# Epochs:   7500 | TrainLoss: 1.466e-03 | Val MSE: 1.110e-05 | Time: 0.30s
# Epochs:   7600 | TrainLoss: 3.804e-04 | Val MSE: 5.291e-06 | Time: 0.29s
# Epochs:   7700 | TrainLoss: 3.414e-04 | Val MSE: 1.439e-07 | Time: 0.30s
# Epochs:   7800 | TrainLoss: 7.287e-04 | Val MSE: 1.659e-06 | Time: 0.30s
# Epochs:   7900 | TrainLoss: 3.224e-04 | Val MSE: 1.385e-07 | Time: 0.31s
# Epochs:   8000 | TrainLoss: 3.539e-04 | Val MSE: 2.230e-07 | Time: 0.30s
# Epochs:   8100 | TrainLoss: 1.000e-03 | Val MSE: 4.756e-06 | Time: 0.30s
# Epochs:   8200 | TrainLoss: 2.970e-04 | Val MSE: 1.304e-07 | Time: 0.30s
# Epochs:   8300 | TrainLoss: 3.584e-04 | Val MSE: 3.456e-07 | Time: 0.30s
# Epochs:   8400 | TrainLoss: 3.063e-04 | Val MSE: 3.011e-07 | Time: 0.31s
# Epochs:   8500 | TrainLoss: 2.844e-04 | Val MSE: 2.109e-07 | Time: 0.29s
# Epochs:   8600 | TrainLoss: 2.698e-04 | Val MSE: 1.513e-07 | Time: 0.29s
# Epochs:   8700 | TrainLoss: 3.712e-04 | Val MSE: 1.874e-07 | Time: 0.30s
# Epochs:   8800 | TrainLoss: 2.552e-04 | Val MSE: 1.269e-07 | Time: 0.29s
# Epochs:   8900 | TrainLoss: 2.527e-03 | Val MSE: 2.996e-06 | Time: 0.29s
# Epochs:   9000 | TrainLoss: 2.448e-04 | Val MSE: 1.504e-07 | Time: 0.30s
# Epochs:   9100 | TrainLoss: 2.402e-04 | Val MSE: 1.080e-07 | Time: 0.29s
# Epochs:   9200 | TrainLoss: 2.459e-03 | Val MSE: 8.998e-06 | Time: 0.30s
# Epochs:   9300 | TrainLoss: 2.585e-04 | Val MSE: 2.443e-07 | Time: 0.29s
# Epochs:   9400 | TrainLoss: 2.193e-04 | Val MSE: 9.517e-08 | Time: 0.29s
# Epochs:   9500 | TrainLoss: 2.175e-04 | Val MSE: 1.529e-07 | Time: 0.29s
# Epochs:   9600 | TrainLoss: 2.171e-04 | Val MSE: 1.340e-07 | Time: 0.29s
# Epochs:   9700 | TrainLoss: 3.795e-04 | Val MSE: 1.938e-06 | Time: 0.31s
# Epochs:   9800 | TrainLoss: 2.037e-04 | Val MSE: 1.006e-07 | Time: 0.29s
# Epochs:   9900 | TrainLoss: 1.976e-04 | Val MSE: 1.193e-07 | Time: 0.29s
# Epochs:  10000 | TrainLoss: 4.829e-03 | Val MSE: 1.101e-05 | Time: 0.30s
# Epochs:  10100 | TrainLoss: 1.856e-04 | Val MSE: 7.688e-08 | Time: 0.30s
# Epochs:  10200 | TrainLoss: 2.270e-04 | Val MSE: 5.249e-07 | Time: 0.30s
# Epochs:  10300 | TrainLoss: 1.828e-04 | Val MSE: 8.143e-08 | Time: 0.29s
# Epochs:  10400 | TrainLoss: 1.765e-04 | Val MSE: 1.474e-07 | Time: 0.29s
# Epochs:  10500 | TrainLoss: 1.705e-04 | Val MSE: 7.348e-08 | Time: 0.31s
# Epochs:  10600 | TrainLoss: 7.487e-04 | Val MSE: 3.945e-06 | Time: 0.29s
# Epochs:  10700 | TrainLoss: 1.711e-04 | Val MSE: 1.308e-07 | Time: 0.29s
# Epochs:  10800 | TrainLoss: 1.632e-04 | Val MSE: 8.444e-08 | Time: 0.29s
# Epochs:  10900 | TrainLoss: 2.453e-04 | Val MSE: 1.338e-06 | Time: 0.30s
# Epochs:  11000 | TrainLoss: 1.933e-04 | Val MSE: 1.889e-07 | Time: 0.29s
# Epochs:  11100 | TrainLoss: 1.700e-04 | Val MSE: 1.726e-07 | Time: 0.29s
# Epochs:  11200 | TrainLoss: 1.513e-04 | Val MSE: 6.897e-08 | Time: 0.29s
# Epochs:  11300 | TrainLoss: 4.872e-04 | Val MSE: 2.133e-06 | Time: 0.29s
# Epochs:  11400 | TrainLoss: 1.446e-04 | Val MSE: 5.136e-08 | Time: 0.29s
# Epochs:  11500 | TrainLoss: 1.094e-02 | Val MSE: 4.104e-05 | Time: 0.31s
# Epochs:  11600 | TrainLoss: 1.384e-04 | Val MSE: 5.618e-08 | Time: 0.29s
# Epochs:  11700 | TrainLoss: 1.467e-04 | Val MSE: 1.665e-07 | Time: 0.30s
# Epochs:  11800 | TrainLoss: 1.351e-04 | Val MSE: 7.245e-08 | Time: 0.29s
# Epochs:  11900 | TrainLoss: 1.705e-04 | Val MSE: 8.557e-07 | Time: 0.29s
# Epochs:  12000 | TrainLoss: 1.294e-04 | Val MSE: 5.172e-08 | Time: 0.30s
# Epochs:  12100 | TrainLoss: 1.416e-04 | Val MSE: 1.221e-07 | Time: 0.30s
# Epochs:  12200 | TrainLoss: 1.287e-04 | Val MSE: 5.214e-08 | Time: 0.29s
# Epochs:  12300 | TrainLoss: 1.233e-04 | Val MSE: 4.885e-08 | Time: 0.32s
# Epochs:  12400 | TrainLoss: 1.631e-04 | Val MSE: 1.323e-06 | Time: 0.30s
# Epochs:  12500 | TrainLoss: 1.316e-04 | Val MSE: 1.676e-07 | Time: 0.30s
# Epochs:  12600 | TrainLoss: 1.232e-04 | Val MSE: 7.241e-08 | Time: 0.29s
# Epochs:  12700 | TrainLoss: 1.193e-04 | Val MSE: 5.517e-08 | Time: 0.29s
# Epochs:  12800 | TrainLoss: 3.412e-03 | Val MSE: 2.162e-05 | Time: 0.31s
# Epochs:  12900 | TrainLoss: 1.143e-04 | Val MSE: 4.265e-08 | Time: 0.30s
# Epochs:  13000 | TrainLoss: 1.129e-04 | Val MSE: 1.718e-07 | Time: 0.30s
# Epochs:  13100 | TrainLoss: 1.619e-03 | Val MSE: 2.978e-06 | Time: 0.30s
# Epochs:  13200 | TrainLoss: 1.087e-04 | Val MSE: 4.801e-08 | Time: 0.30s
# Epochs:  13300 | TrainLoss: 8.921e-03 | Val MSE: 2.347e-05 | Time: 0.29s
# Epochs:  13400 | TrainLoss: 4.657e-04 | Val MSE: 3.071e-06 | Time: 0.30s
# Epochs:  13500 | TrainLoss: 2.082e-04 | Val MSE: 6.421e-07 | Time: 0.29s
# Epochs:  13600 | TrainLoss: 1.050e-04 | Val MSE: 4.503e-08 | Time: 0.29s
# Epochs:  13700 | TrainLoss: 1.017e-04 | Val MSE: 3.747e-08 | Time: 0.32s
# Epochs:  13800 | TrainLoss: 1.135e-04 | Val MSE: 1.221e-07 | Time: 0.29s
# Epochs:  13900 | TrainLoss: 1.223e-04 | Val MSE: 7.083e-08 | Time: 0.29s
# Epochs:  14000 | TrainLoss: 4.446e-04 | Val MSE: 2.547e-06 | Time: 0.29s
# Epochs:  14100 | TrainLoss: 1.067e-04 | Val MSE: 7.344e-08 | Time: 0.29s
# Epochs:  14200 | TrainLoss: 1.138e-04 | Val MSE: 1.257e-07 | Time: 0.29s
# Epochs:  14300 | TrainLoss: 9.724e-05 | Val MSE: 2.034e-07 | Time: 0.30s
# Epochs:  14400 | TrainLoss: 3.165e-04 | Val MSE: 1.838e-06 | Time: 0.29s
# Epochs:  14500 | TrainLoss: 9.313e-05 | Val MSE: 3.276e-08 | Time: 0.30s
# Epochs:  14600 | TrainLoss: 2.497e-04 | Val MSE: 3.498e-06 | Time: 0.31s
# Epochs:  14700 | TrainLoss: 9.445e-05 | Val MSE: 5.313e-08 | Time: 0.29s
# Epochs:  14800 | TrainLoss: 1.309e-04 | Val MSE: 3.618e-07 | Time: 0.29s
# Epochs:  14900 | TrainLoss: 1.866e-04 | Val MSE: 5.544e-07 | Time: 0.29s
# Epochs:  15000 | TrainLoss: 9.073e-05 | Val MSE: 4.050e-08 | Time: 0.29s
# Epochs:  15100 | TrainLoss: 1.247e-04 | Val MSE: 2.947e-07 | Time: 0.30s
# Epochs:  15200 | TrainLoss: 8.778e-05 | Val MSE: 2.865e-08 | Time: 0.29s
# Epochs:  15300 | TrainLoss: 1.253e-04 | Val MSE: 1.451e-07 | Time: 0.30s
# Epochs:  15400 | TrainLoss: 8.675e-04 | Val MSE: 3.417e-06 | Time: 0.32s
# Epochs:  15500 | TrainLoss: 9.869e-05 | Val MSE: 6.873e-08 | Time: 0.31s
# Epochs:  15600 | TrainLoss: 3.698e-04 | Val MSE: 8.083e-07 | Time: 0.31s
# Epochs:  15700 | TrainLoss: 2.302e-04 | Val MSE: 8.957e-07 | Time: 0.31s
# Epochs:  15800 | TrainLoss: 2.177e-04 | Val MSE: 2.313e-07 | Time: 0.31s
# Epochs:  15900 | TrainLoss: 1.929e-04 | Val MSE: 4.499e-07 | Time: 0.30s
# Epochs:  16000 | TrainLoss: 8.076e-05 | Val MSE: 2.738e-08 | Time: 0.32s
# Epochs:  16100 | TrainLoss: 9.450e-05 | Val MSE: 7.902e-08 | Time: 0.31s
# Epochs:  16200 | TrainLoss: 3.709e-03 | Val MSE: 1.285e-06 | Time: 0.32s
# Epochs:  16300 | TrainLoss: 1.341e-02 | Val MSE: 4.624e-05 | Time: 0.31s
# Epochs:  16400 | TrainLoss: 7.826e-05 | Val MSE: 2.397e-08 | Time: 0.31s
# Epochs:  16500 | TrainLoss: 3.153e-03 | Val MSE: 1.424e-05 | Time: 0.32s
# Epochs:  16600 | TrainLoss: 7.733e-05 | Val MSE: 2.335e-08 | Time: 0.31s
# Epochs:  16700 | TrainLoss: 7.782e-05 | Val MSE: 1.376e-06 | Time: 0.31s
# Epochs:  16800 | TrainLoss: 5.089e-04 | Val MSE: 2.988e-06 | Time: 0.29s
# Epochs:  16900 | TrainLoss: 7.547e-05 | Val MSE: 2.278e-08 | Time: 0.30s
# Epochs:  17000 | TrainLoss: 1.749e-04 | Val MSE: 4.474e-07 | Time: 0.31s
# Epochs:  17100 | TrainLoss: 1.150e-04 | Val MSE: 1.198e-07 | Time: 0.29s
# Epochs:  17200 | TrainLoss: 1.185e-03 | Val MSE: 2.487e-06 | Time: 0.29s
# Epochs:  17300 | TrainLoss: 7.319e-05 | Val MSE: 2.101e-08 | Time: 0.29s
# Epochs:  17400 | TrainLoss: 7.722e-05 | Val MSE: 3.801e-08 | Time: 0.29s
# Epochs:  17500 | TrainLoss: 7.227e-05 | Val MSE: 2.114e-08 | Time: 0.31s
# Epochs:  17600 | TrainLoss: 7.532e-05 | Val MSE: 4.083e-08 | Time: 0.29s
# Epochs:  17700 | TrainLoss: 7.366e-05 | Val MSE: 1.010e-07 | Time: 0.29s
# Epochs:  17800 | TrainLoss: 4.611e-04 | Val MSE: 2.464e-06 | Time: 0.30s
# Epochs:  17900 | TrainLoss: 7.198e-05 | Val MSE: 2.653e-08 | Time: 0.29s
# Epochs:  18000 | TrainLoss: 1.023e-04 | Val MSE: 4.073e-07 | Time: 0.30s
# Epochs:  18100 | TrainLoss: 7.386e-05 | Val MSE: 5.637e-08 | Time: 0.29s
# Epochs:  18200 | TrainLoss: 2.492e-03 | Val MSE: 2.597e-06 | Time: 0.29s
# Epochs:  18300 | TrainLoss: 6.890e-05 | Val MSE: 1.936e-08 | Time: 0.29s
# Epochs:  18400 | TrainLoss: 2.093e-04 | Val MSE: 2.974e-06 | Time: 0.30s
# Epochs:  18500 | TrainLoss: 1.556e-04 | Val MSE: 3.931e-07 | Time: 0.29s
# Epochs:  18600 | TrainLoss: 1.595e-04 | Val MSE: 5.290e-08 | Time: 0.29s
# Epochs:  18700 | TrainLoss: 2.557e-04 | Val MSE: 3.734e-06 | Time: 0.29s
# Epochs:  18800 | TrainLoss: 1.677e-04 | Val MSE: 4.476e-07 | Time: 0.29s
# Epochs:  18900 | TrainLoss: 2.118e-03 | Val MSE: 1.896e-05 | Time: 0.29s
# Epochs:  19000 | TrainLoss: 7.910e-03 | Val MSE: 4.013e-05 | Time: 0.29s
# Epochs:  19100 | TrainLoss: 6.621e-05 | Val MSE: 2.099e-08 | Time: 0.29s
# Epochs:  19200 | TrainLoss: 1.129e-04 | Val MSE: 6.343e-06 | Time: 0.30s
# Epochs:  19300 | TrainLoss: 6.685e-05 | Val MSE: 3.242e-08 | Time: 0.29s
# Epochs:  19400 | TrainLoss: 6.546e-05 | Val MSE: 2.029e-08 | Time: 0.29s
# Epochs:  19500 | TrainLoss: 1.305e-03 | Val MSE: 1.501e-05 | Time: 0.30s
# Epochs:  19600 | TrainLoss: 6.423e-05 | Val MSE: 1.844e-08 | Time: 0.29s
# Epochs:  19700 | TrainLoss: 6.576e-05 | Val MSE: 2.546e-08 | Time: 0.29s
# Epochs:  19800 | TrainLoss: 2.263e-03 | Val MSE: 1.290e-05 | Time: 0.30s
# Epochs:  19900 | TrainLoss: 6.304e-05 | Val MSE: 1.694e-08 | Time: 0.30s
# Epochs:  20000 | TrainLoss: 1.054e-04 | Val MSE: 4.948e-07 | Time: 0.30s
# Epochs:  20100 | TrainLoss: 6.243e-05 | Val MSE: 1.699e-08 | Time: 0.30s
# Epochs:  20200 | TrainLoss: 2.640e-04 | Val MSE: 7.213e-07 | Time: 0.30s
# Epochs:  20300 | TrainLoss: 6.187e-05 | Val MSE: 1.601e-08 | Time: 0.30s
# Epochs:  20400 | TrainLoss: 8.281e-05 | Val MSE: 9.078e-08 | Time: 0.29s
# Epochs:  20500 | TrainLoss: 1.192e-03 | Val MSE: 5.084e-06 | Time: 0.29s
# Epochs:  20600 | TrainLoss: 6.099e-05 | Val MSE: 1.652e-08 | Time: 0.30s
# Epochs:  20700 | TrainLoss: 9.004e-05 | Val MSE: 8.748e-07 | Time: 0.30s
# Epochs:  20800 | TrainLoss: 6.050e-05 | Val MSE: 1.591e-08 | Time: 0.30s
# Epochs:  20900 | TrainLoss: 8.740e-05 | Val MSE: 1.158e-07 | Time: 0.30s
# Epochs:  21000 | TrainLoss: 7.629e-05 | Val MSE: 3.575e-07 | Time: 0.30s
# Epochs:  21100 | TrainLoss: 4.179e-03 | Val MSE: 1.657e-05 | Time: 0.29s
# Epochs:  21200 | TrainLoss: 3.976e-03 | Val MSE: 2.045e-05 | Time: 0.29s
# Epochs:  21300 | TrainLoss: 4.476e-04 | Val MSE: 1.872e-06 | Time: 0.29s
# Epochs:  21400 | TrainLoss: 3.106e-04 | Val MSE: 1.562e-06 | Time: 0.31s
# Epochs:  21500 | TrainLoss: 6.046e-05 | Val MSE: 1.905e-08 | Time: 0.31s
# Epochs:  21600 | TrainLoss: 7.916e-05 | Val MSE: 3.569e-07 | Time: 0.31s
# Epochs:  21700 | TrainLoss: 2.485e-03 | Val MSE: 3.288e-05 | Time: 0.31s
# Epochs:  21800 | TrainLoss: 5.795e-05 | Val MSE: 1.593e-08 | Time: 0.31s
# Epochs:  21900 | TrainLoss: 1.533e-03 | Val MSE: 7.545e-06 | Time: 0.32s
# Epochs:  22000 | TrainLoss: 5.755e-05 | Val MSE: 1.463e-08 | Time: 0.31s
# Epochs:  22100 | TrainLoss: 6.590e-05 | Val MSE: 1.112e-07 | Time: 0.31s
# Epochs:  22200 | TrainLoss: 1.746e-03 | Val MSE: 6.577e-06 | Time: 0.31s
# Epochs:  22300 | TrainLoss: 5.677e-05 | Val MSE: 1.433e-08 | Time: 0.31s
# Epochs:  22400 | TrainLoss: 2.393e-04 | Val MSE: 1.812e-06 | Time: 0.33s
# Epochs:  22500 | TrainLoss: 6.151e-04 | Val MSE: 2.312e-06 | Time: 0.31s
# Epochs:  22600 | TrainLoss: 6.968e-03 | Val MSE: 4.115e-05 | Time: 0.31s
# Epochs:  22700 | TrainLoss: 5.737e-03 | Val MSE: 1.620e-05 | Time: 0.31s
# Epochs:  22800 | TrainLoss: 5.673e-05 | Val MSE: 2.201e-08 | Time: 0.31s
# Epochs:  22900 | TrainLoss: 5.573e-05 | Val MSE: 2.440e-08 | Time: 0.31s
# Epochs:  23000 | TrainLoss: 1.089e-04 | Val MSE: 1.462e-07 | Time: 0.31s
# Epochs:  23100 | TrainLoss: 1.205e-02 | Val MSE: 4.311e-05 | Time: 0.31s
# Epochs:  23200 | TrainLoss: 5.513e-05 | Val MSE: 1.449e-08 | Time: 0.31s
# Epochs:  23300 | TrainLoss: 6.707e-05 | Val MSE: 8.980e-08 | Time: 0.31s
# Epochs:  23400 | TrainLoss: 6.332e-05 | Val MSE: 5.844e-08 | Time: 0.31s
# Epochs:  23500 | TrainLoss: 1.411e-04 | Val MSE: 4.920e-07 | Time: 0.31s
# Epochs:  23600 | TrainLoss: 5.602e-05 | Val MSE: 2.302e-08 | Time: 0.31s
# Epochs:  23700 | TrainLoss: 8.349e-05 | Val MSE: 1.057e-07 | Time: 0.31s
# Epochs:  23800 | TrainLoss: 7.160e-05 | Val MSE: 1.393e-07 | Time: 0.31s
# Epochs:  23900 | TrainLoss: 1.083e-03 | Val MSE: 5.680e-06 | Time: 0.31s
# Epochs:  24000 | TrainLoss: 5.297e-05 | Val MSE: 1.500e-08 | Time: 0.31s
# Epochs:  24100 | TrainLoss: 5.313e-05 | Val MSE: 4.935e-08 | Time: 0.31s
# Epochs:  24200 | TrainLoss: 7.770e-05 | Val MSE: 1.852e-07 | Time: 0.30s
# Epochs:  24300 | TrainLoss: 2.109e-03 | Val MSE: 1.766e-05 | Time: 0.31s
# Epochs:  24400 | TrainLoss: 5.229e-05 | Val MSE: 1.397e-08 | Time: 0.31s
# Epochs:  24500 | TrainLoss: 6.125e-05 | Val MSE: 1.225e-07 | Time: 0.31s
# Epochs:  24600 | TrainLoss: 8.282e-03 | Val MSE: 1.460e-05 | Time: 0.32s
# Epochs:  24700 | TrainLoss: 5.210e-05 | Val MSE: 1.473e-08 | Time: 0.31s
# Epochs:  24800 | TrainLoss: 1.643e-02 | Val MSE: 6.034e-05 | Time: 0.33s
# Epochs:  24900 | TrainLoss: 5.167e-05 | Val MSE: 1.361e-08 | Time: 0.31s
# Epochs:  25000 | TrainLoss: 5.096e-05 | Val MSE: 1.352e-08 | Time: 0.34s
# Epochs:  25100 | TrainLoss: 5.413e-05 | Val MSE: 9.950e-08 | Time: 0.31s
# Epochs:  25200 | TrainLoss: 5.080e-05 | Val MSE: 1.283e-08 | Time: 0.32s
# Epochs:  25300 | TrainLoss: 5.603e-05 | Val MSE: 1.657e-08 | Time: 0.31s
# Epochs:  25400 | TrainLoss: 9.493e-05 | Val MSE: 3.598e-07 | Time: 0.31s
# Epochs:  25500 | TrainLoss: 1.986e-03 | Val MSE: 9.541e-06 | Time: 0.31s
# Epochs:  25600 | TrainLoss: 1.882e-04 | Val MSE: 8.018e-07 | Time: 0.31s
# Epochs:  25700 | TrainLoss: 5.102e-05 | Val MSE: 1.712e-08 | Time: 0.31s
# Epochs:  25800 | TrainLoss: 5.952e-05 | Val MSE: 1.868e-08 | Time: 0.31s
# Epochs:  25900 | TrainLoss: 6.646e-05 | Val MSE: 9.406e-08 | Time: 0.31s
# Epochs:  26000 | TrainLoss: 1.229e-04 | Val MSE: 2.664e-07 | Time: 0.31s
# Epochs:  26100 | TrainLoss: 1.431e-04 | Val MSE: 1.248e-06 | Time: 0.31s
# Epochs:  26200 | TrainLoss: 1.125e-03 | Val MSE: 4.905e-06 | Time: 0.31s
# Epochs:  26300 | TrainLoss: 7.630e-04 | Val MSE: 2.250e-06 | Time: 0.31s
# Epochs:  26400 | TrainLoss: 7.369e-05 | Val MSE: 1.809e-07 | Time: 0.34s
# Epochs:  26500 | TrainLoss: 8.604e-05 | Val MSE: 7.751e-08 | Time: 0.34s
# Epochs:  26600 | TrainLoss: 1.149e-04 | Val MSE: 2.925e-07 | Time: 0.33s
# Epochs:  26700 | TrainLoss: 5.780e-05 | Val MSE: 6.271e-08 | Time: 0.33s
# Epochs:  26800 | TrainLoss: 5.147e-03 | Val MSE: 2.888e-05 | Time: 0.31s
# Epochs:  26900 | TrainLoss: 5.452e-05 | Val MSE: 4.429e-08 | Time: 0.30s
# Epochs:  27000 | TrainLoss: 6.002e-05 | Val MSE: 1.185e-07 | Time: 0.29s
# Epochs:  27100 | TrainLoss: 1.836e-03 | Val MSE: 2.010e-05 | Time: 0.29s
# Epochs:  27200 | TrainLoss: 4.939e-05 | Val MSE: 2.375e-08 | Time: 0.29s
# Epochs:  27300 | TrainLoss: 1.236e-04 | Val MSE: 2.063e-07 | Time: 0.29s
# Epochs:  27400 | TrainLoss: 4.983e-05 | Val MSE: 8.256e-08 | Time: 0.29s
# Epochs:  27500 | TrainLoss: 1.216e-04 | Val MSE: 2.908e-07 | Time: 0.29s
# Epochs:  27600 | TrainLoss: 1.892e-03 | Val MSE: 1.918e-05 | Time: 0.30s
# Epochs:  27700 | TrainLoss: 7.645e-04 | Val MSE: 1.558e-06 | Time: 0.29s
# Epochs:  27800 | TrainLoss: 5.843e-05 | Val MSE: 4.649e-07 | Time: 0.29s
# Epochs:  27900 | TrainLoss: 7.294e-05 | Val MSE: 3.287e-07 | Time: 0.29s
# Epochs:  28000 | TrainLoss: 4.642e-05 | Val MSE: 1.567e-08 | Time: 0.30s
# Epochs:  28100 | TrainLoss: 5.385e-05 | Val MSE: 9.123e-08 | Time: 0.29s
# Epochs:  28200 | TrainLoss: 6.089e-05 | Val MSE: 1.618e-07 | Time: 0.29s
# Epochs:  28300 | TrainLoss: 7.016e-05 | Val MSE: 1.049e-07 | Time: 0.29s
# Epochs:  28400 | TrainLoss: 3.173e-04 | Val MSE: 2.707e-06 | Time: 0.29s
# Epochs:  28500 | TrainLoss: 3.414e-04 | Val MSE: 8.397e-07 | Time: 0.29s
# Epochs:  28600 | TrainLoss: 6.014e-05 | Val MSE: 2.685e-07 | Time: 0.29s
# Epochs:  28700 | TrainLoss: 4.703e-05 | Val MSE: 1.628e-08 | Time: 0.29s
# Epochs:  28800 | TrainLoss: 1.265e-04 | Val MSE: 2.367e-07 | Time: 0.29s
# Epochs:  28900 | TrainLoss: 1.343e-03 | Val MSE: 8.337e-06 | Time: 0.29s
# Epochs:  29000 | TrainLoss: 4.462e-05 | Val MSE: 1.189e-08 | Time: 0.29s
# Epochs:  29100 | TrainLoss: 7.961e-04 | Val MSE: 5.424e-06 | Time: 0.29s
# Epochs:  29200 | TrainLoss: 4.498e-05 | Val MSE: 1.527e-08 | Time: 0.29s
# Epochs:  29300 | TrainLoss: 7.788e-05 | Val MSE: 1.659e-08 | Time: 0.29s
# Epochs:  29400 | TrainLoss: 6.812e-04 | Val MSE: 2.797e-06 | Time: 0.29s
# Epochs:  29500 | TrainLoss: 4.456e-05 | Val MSE: 1.341e-08 | Time: 0.29s
# Epochs:  29600 | TrainLoss: 4.749e-05 | Val MSE: 2.784e-08 | Time: 0.29s
# Epochs:  29700 | TrainLoss: 4.736e-05 | Val MSE: 1.748e-08 | Time: 0.29s
# Epochs:  29800 | TrainLoss: 6.726e-04 | Val MSE: 1.004e-05 | Time: 0.30s
# Epochs:  29900 | TrainLoss: 4.505e-03 | Val MSE: 1.174e-05 | Time: 0.29s
# Epochs:  30000 | TrainLoss: 9.292e-05 | Val MSE: 3.216e-07 | Time: 0.29s
# Epochs:  30100 | TrainLoss: 4.449e-05 | Val MSE: 1.698e-08 | Time: 0.29s
# Epochs:  30200 | TrainLoss: 4.622e-05 | Val MSE: 1.983e-08 | Time: 0.29s
# Epochs:  30300 | TrainLoss: 3.235e-03 | Val MSE: 3.291e-05 | Time: 0.30s
# Epochs:  30400 | TrainLoss: 4.335e-05 | Val MSE: 1.852e-08 | Time: 0.29s
# Epochs:  30500 | TrainLoss: 6.106e-05 | Val MSE: 2.072e-07 | Time: 0.29s
# Epochs:  30600 | TrainLoss: 4.549e-03 | Val MSE: 1.604e-05 | Time: 0.29s
# Epochs:  30700 | TrainLoss: 4.259e-05 | Val MSE: 1.078e-08 | Time: 0.29s
# Epochs:  30800 | TrainLoss: 4.301e-05 | Val MSE: 1.079e-08 | Time: 0.29s
# Epochs:  30900 | TrainLoss: 7.015e-05 | Val MSE: 2.420e-07 | Time: 0.29s
# Epochs:  31000 | TrainLoss: 2.959e-04 | Val MSE: 6.771e-06 | Time: 0.29s
# Epochs:  31100 | TrainLoss: 5.376e-03 | Val MSE: 2.722e-05 | Time: 0.29s
# Epochs:  31200 | TrainLoss: 1.702e-03 | Val MSE: 1.804e-05 | Time: 0.29s
# Epochs:  31300 | TrainLoss: 4.148e-05 | Val MSE: 1.109e-08 | Time: 0.29s
# Epochs:  31400 | TrainLoss: 9.495e-05 | Val MSE: 1.147e-07 | Time: 0.29s
# Epochs:  31500 | TrainLoss: 6.461e-03 | Val MSE: 3.802e-05 | Time: 0.29s
# Epochs:  31600 | TrainLoss: 4.171e-05 | Val MSE: 1.352e-08 | Time: 0.29s
# Epochs:  31700 | TrainLoss: 4.322e-05 | Val MSE: 5.315e-08 | Time: 0.29s
# Epochs:  31800 | TrainLoss: 2.421e-03 | Val MSE: 3.821e-05 | Time: 0.30s
# Epochs:  31900 | TrainLoss: 6.458e-04 | Val MSE: 3.504e-06 | Time: 0.29s
# Epochs:  32000 | TrainLoss: 4.341e-05 | Val MSE: 3.199e-08 | Time: 0.29s
# Epochs:  32100 | TrainLoss: 4.289e-05 | Val MSE: 1.506e-08 | Time: 0.29s
# Epochs:  32200 | TrainLoss: 3.696e-03 | Val MSE: 9.470e-06 | Time: 0.30s
# Epochs:  32300 | TrainLoss: 4.052e-05 | Val MSE: 1.154e-08 | Time: 0.29s
# Epochs:  32400 | TrainLoss: 1.741e-04 | Val MSE: 7.359e-07 | Time: 0.31s
# Epochs:  32500 | TrainLoss: 4.115e-05 | Val MSE: 1.213e-08 | Time: 0.29s
# Epochs:  32600 | TrainLoss: 3.394e-03 | Val MSE: 6.016e-05 | Time: 0.30s
# Epochs:  32700 | TrainLoss: 3.970e-05 | Val MSE: 1.293e-08 | Time: 0.29s
# Epochs:  32800 | TrainLoss: 9.049e-05 | Val MSE: 9.086e-08 | Time: 0.29s
# Epochs:  32900 | TrainLoss: 1.434e-04 | Val MSE: 4.423e-07 | Time: 0.29s
# Epochs:  33000 | TrainLoss: 7.406e-03 | Val MSE: 1.528e-05 | Time: 0.29s
# Epochs:  33100 | TrainLoss: 3.969e-05 | Val MSE: 1.186e-08 | Time: 0.29s
# Epochs:  33200 | TrainLoss: 3.969e-05 | Val MSE: 3.588e-08 | Time: 0.29s
# Epochs:  33300 | TrainLoss: 1.192e-04 | Val MSE: 9.545e-07 | Time: 0.29s
# Epochs:  33400 | TrainLoss: 3.908e-05 | Val MSE: 1.610e-08 | Time: 0.30s
# Epochs:  33500 | TrainLoss: 6.315e-05 | Val MSE: 1.484e-07 | Time: 0.29s
# Epochs:  33600 | TrainLoss: 4.016e-05 | Val MSE: 2.258e-08 | Time: 0.29s
# Epochs:  33700 | TrainLoss: 4.049e-05 | Val MSE: 1.104e-08 | Time: 0.29s
# Epochs:  33800 | TrainLoss: 5.237e-05 | Val MSE: 1.056e-07 | Time: 0.29s
# Epochs:  33900 | TrainLoss: 7.564e-03 | Val MSE: 1.940e-05 | Time: 0.29s
# Epochs:  34000 | TrainLoss: 4.389e-05 | Val MSE: 6.695e-08 | Time: 0.29s
# Epochs:  34100 | TrainLoss: 3.914e-05 | Val MSE: 1.973e-08 | Time: 0.29s
# Epochs:  34200 | TrainLoss: 3.641e-04 | Val MSE: 5.734e-06 | Time: 0.30s
# Epochs:  34300 | TrainLoss: 1.085e-03 | Val MSE: 5.759e-06 | Time: 0.29s
# Epochs:  34400 | TrainLoss: 9.035e-04 | Val MSE: 9.016e-08 | Time: 0.29s
# Epochs:  34500 | TrainLoss: 4.292e-03 | Val MSE: 5.256e-06 | Time: 0.29s
# Epochs:  34600 | TrainLoss: 3.760e-05 | Val MSE: 9.695e-09 | Time: 0.29s
# Epochs:  34700 | TrainLoss: 8.916e-03 | Val MSE: 5.644e-05 | Time: 0.31s
# Epochs:  34800 | TrainLoss: 3.747e-05 | Val MSE: 1.130e-08 | Time: 0.29s
# Epochs:  34900 | TrainLoss: 3.725e-05 | Val MSE: 1.494e-08 | Time: 0.29s
# Epochs:  35000 | TrainLoss: 1.060e-04 | Val MSE: 3.097e-07 | Time: 0.29s
# Epochs:  35100 | TrainLoss: 4.655e-05 | Val MSE: 6.454e-08 | Time: 0.29s
# Epochs:  35200 | TrainLoss: 2.289e-04 | Val MSE: 4.244e-07 | Time: 0.29s
# Epochs:  35300 | TrainLoss: 4.182e-04 | Val MSE: 3.144e-06 | Time: 0.29s
# Epochs:  35400 | TrainLoss: 3.765e-05 | Val MSE: 1.368e-08 | Time: 0.29s
# Epochs:  35500 | TrainLoss: 4.578e-05 | Val MSE: 8.014e-08 | Time: 0.29s
# Epochs:  35600 | TrainLoss: 7.165e-05 | Val MSE: 3.219e-07 | Time: 0.29s
# Epochs:  35700 | TrainLoss: 3.943e-03 | Val MSE: 1.925e-05 | Time: 0.29s
# Epochs:  35800 | TrainLoss: 5.332e-05 | Val MSE: 1.837e-07 | Time: 0.29s
# Epochs:  35900 | TrainLoss: 3.302e-04 | Val MSE: 3.909e-07 | Time: 0.29s
# Epochs:  36000 | TrainLoss: 2.208e-03 | Val MSE: 1.476e-05 | Time: 0.29s
# Epochs:  36100 | TrainLoss: 7.665e-03 | Val MSE: 7.562e-05 | Time: 0.29s
# Epochs:  36200 | TrainLoss: 3.604e-05 | Val MSE: 1.136e-08 | Time: 0.29s
# Epochs:  36300 | TrainLoss: 7.001e-05 | Val MSE: 2.282e-07 | Time: 0.29s
# Epochs:  36400 | TrainLoss: 5.513e-03 | Val MSE: 2.081e-05 | Time: 0.29s
# Epochs:  36500 | TrainLoss: 3.544e-05 | Val MSE: 9.688e-09 | Time: 0.29s
# Epochs:  36600 | TrainLoss: 1.152e-02 | Val MSE: 4.065e-05 | Time: 0.31s
# Epochs:  36700 | TrainLoss: 3.604e-05 | Val MSE: 2.937e-08 | Time: 0.29s
# Epochs:  36800 | TrainLoss: 6.149e-05 | Val MSE: 1.060e-07 | Time: 0.29s
# Epochs:  36900 | TrainLoss: 3.976e-05 | Val MSE: 4.343e-08 | Time: 0.29s
# Epochs:  37000 | TrainLoss: 3.496e-05 | Val MSE: 1.112e-08 | Time: 0.29s
# Epochs:  37100 | TrainLoss: 4.770e-05 | Val MSE: 3.510e-08 | Time: 0.29s
# Epochs:  37200 | TrainLoss: 4.010e-05 | Val MSE: 2.789e-08 | Time: 0.29s
# Epochs:  37300 | TrainLoss: 5.074e-03 | Val MSE: 1.349e-05 | Time: 0.29s
# Epochs:  37400 | TrainLoss: 2.216e-04 | Val MSE: 1.666e-06 | Time: 0.29s
# Epochs:  37500 | TrainLoss: 1.492e-04 | Val MSE: 1.261e-07 | Time: 0.29s
# Epochs:  37600 | TrainLoss: 3.426e-05 | Val MSE: 1.323e-08 | Time: 0.30s
# Epochs:  37700 | TrainLoss: 4.622e-05 | Val MSE: 7.035e-08 | Time: 0.29s
# Epochs:  37800 | TrainLoss: 1.827e-03 | Val MSE: 8.040e-06 | Time: 0.30s
# Epochs:  37900 | TrainLoss: 1.803e-04 | Val MSE: 1.681e-06 | Time: 0.31s
# Epochs:  38000 | TrainLoss: 3.370e-05 | Val MSE: 9.478e-09 | Time: 0.32s
# Epochs:  38100 | TrainLoss: 3.744e-05 | Val MSE: 1.503e-07 | Time: 0.31s
# Epochs:  38200 | TrainLoss: 4.209e-05 | Val MSE: 7.228e-08 | Time: 0.31s
# Epochs:  38300 | TrainLoss: 2.296e-04 | Val MSE: 1.132e-06 | Time: 0.33s
# Epochs:  38400 | TrainLoss: 4.975e-03 | Val MSE: 1.274e-05 | Time: 0.29s
# Epochs:  38500 | TrainLoss: 3.323e-05 | Val MSE: 9.151e-09 | Time: 0.29s
# Epochs:  38600 | TrainLoss: 7.779e-05 | Val MSE: 5.324e-08 | Time: 0.29s
# Epochs:  38700 | TrainLoss: 1.462e-03 | Val MSE: 4.151e-06 | Time: 0.29s
# Epochs:  38800 | TrainLoss: 1.746e-03 | Val MSE: 1.238e-05 | Time: 0.29s
# Epochs:  38900 | TrainLoss: 3.338e-05 | Val MSE: 9.515e-09 | Time: 0.29s
# Epochs:  39000 | TrainLoss: 6.174e-05 | Val MSE: 8.406e-08 | Time: 0.29s
# Epochs:  39100 | TrainLoss: 3.666e-05 | Val MSE: 2.194e-08 | Time: 0.29s
# Epochs:  39200 | TrainLoss: 1.438e-03 | Val MSE: 8.721e-06 | Time: 0.29s
# Epochs:  39300 | TrainLoss: 3.258e-05 | Val MSE: 1.076e-08 | Time: 0.29s
# Epochs:  39400 | TrainLoss: 1.706e-03 | Val MSE: 1.354e-05 | Time: 0.30s
# Epochs:  39500 | TrainLoss: 3.240e-05 | Val MSE: 1.137e-08 | Time: 0.29s
# Epochs:  39600 | TrainLoss: 4.862e-05 | Val MSE: 5.475e-08 | Time: 0.29s
# Epochs:  39700 | TrainLoss: 3.285e-05 | Val MSE: 9.467e-09 | Time: 0.29s
# Epochs:  39800 | TrainLoss: 4.695e-05 | Val MSE: 8.376e-08 | Time: 0.29s
# Epochs:  39900 | TrainLoss: 1.833e-03 | Val MSE: 1.418e-05 | Time: 0.29s
# Epochs:  40000 | TrainLoss: 3.292e-05 | Val MSE: 1.949e-08 | Time: 0.29s
# Epochs:  40100 | TrainLoss: 3.374e-05 | Val MSE: 1.673e-08 | Time: 0.29s
# Epochs:  40200 | TrainLoss: 4.313e-05 | Val MSE: 3.107e-07 | Time: 0.29s
# Epochs:  40300 | TrainLoss: 3.804e-05 | Val MSE: 4.517e-08 | Time: 0.29s
# Epochs:  40400 | TrainLoss: 1.791e-04 | Val MSE: 7.645e-07 | Time: 0.29s
# Epochs:  40500 | TrainLoss: 3.453e-05 | Val MSE: 9.120e-09 | Time: 0.29s
# Epochs:  40600 | TrainLoss: 1.656e-04 | Val MSE: 1.095e-06 | Time: 0.30s
# Epochs:  40700 | TrainLoss: 3.243e-05 | Val MSE: 1.135e-08 | Time: 0.29s
# Epochs:  40800 | TrainLoss: 6.683e-05 | Val MSE: 2.093e-07 | Time: 0.29s
# Epochs:  40900 | TrainLoss: 1.531e-03 | Val MSE: 2.466e-06 | Time: 0.29s
# Epochs:  41000 | TrainLoss: 6.163e-05 | Val MSE: 1.941e-07 | Time: 0.29s
# Epochs:  41100 | TrainLoss: 6.866e-05 | Val MSE: 2.086e-07 | Time: 0.29s
# Epochs:  41200 | TrainLoss: 3.785e-05 | Val MSE: 9.766e-08 | Time: 0.29s
# Epochs:  41300 | TrainLoss: 3.420e-05 | Val MSE: 4.076e-08 | Time: 0.29s
# Epochs:  41400 | TrainLoss: 3.892e-05 | Val MSE: 6.886e-08 | Time: 0.29s
# Epochs:  41500 | TrainLoss: 3.263e-05 | Val MSE: 1.707e-08 | Time: 0.29s
# Epochs:  41600 | TrainLoss: 2.978e-04 | Val MSE: 1.339e-06 | Time: 0.29s
# Epochs:  41700 | TrainLoss: 6.279e-05 | Val MSE: 2.595e-07 | Time: 0.29s
# Epochs:  41800 | TrainLoss: 1.031e-02 | Val MSE: 2.910e-05 | Time: 0.29s
# Epochs:  41900 | TrainLoss: 3.020e-05 | Val MSE: 9.018e-09 | Time: 0.29s
# Epochs:  42000 | TrainLoss: 2.139e-03 | Val MSE: 1.099e-05 | Time: 0.31s
# Epochs:  42100 | TrainLoss: 3.022e-05 | Val MSE: 1.232e-08 | Time: 0.29s
# Epochs:  42200 | TrainLoss: 6.717e-04 | Val MSE: 3.105e-06 | Time: 0.30s
# Epochs:  42300 | TrainLoss: 7.961e-03 | Val MSE: 2.621e-05 | Time: 0.29s
# Epochs:  42400 | TrainLoss: 2.967e-05 | Val MSE: 9.509e-09 | Time: 0.29s
# Epochs:  42500 | TrainLoss: 2.760e-04 | Val MSE: 6.726e-07 | Time: 0.30s
# Epochs:  42600 | TrainLoss: 2.947e-05 | Val MSE: 9.835e-09 | Time: 0.29s
# Epochs:  42700 | TrainLoss: 5.733e-05 | Val MSE: 5.152e-08 | Time: 0.29s
# Epochs:  42800 | TrainLoss: 7.876e-05 | Val MSE: 1.764e-07 | Time: 0.29s
# Epochs:  42900 | TrainLoss: 7.323e-05 | Val MSE: 4.592e-07 | Time: 0.29s
# Epochs:  43000 | TrainLoss: 3.079e-05 | Val MSE: 1.030e-08 | Time: 0.29s
# Epochs:  43100 | TrainLoss: 4.605e-05 | Val MSE: 1.440e-07 | Time: 0.31s
# Epochs:  43200 | TrainLoss: 1.079e-04 | Val MSE: 4.926e-07 | Time: 0.29s
# Epochs:  43300 | TrainLoss: 5.059e-05 | Val MSE: 1.223e-07 | Time: 0.29s
# Epochs:  43400 | TrainLoss: 3.892e-05 | Val MSE: 2.476e-08 | Time: 0.29s
# Epochs:  43500 | TrainLoss: 1.380e-03 | Val MSE: 3.138e-06 | Time: 0.29s
# Epochs:  43600 | TrainLoss: 2.866e-05 | Val MSE: 1.021e-08 | Time: 0.29s
# Epochs:  43700 | TrainLoss: 3.183e-05 | Val MSE: 5.379e-08 | Time: 0.29s
# Epochs:  43800 | TrainLoss: 3.494e-05 | Val MSE: 9.702e-08 | Time: 0.29s
# Epochs:  43900 | TrainLoss: 2.097e-03 | Val MSE: 6.475e-06 | Time: 0.30s
# Epochs:  44000 | TrainLoss: 2.860e-05 | Val MSE: 7.714e-09 | Time: 0.29s
# Epochs:  44100 | TrainLoss: 2.030e-04 | Val MSE: 1.413e-06 | Time: 0.30s
# Epochs:  44200 | TrainLoss: 3.726e-05 | Val MSE: 5.611e-08 | Time: 0.29s
# Epochs:  44300 | TrainLoss: 3.255e-05 | Val MSE: 2.036e-08 | Time: 0.29s
# Epochs:  44400 | TrainLoss: 7.060e-05 | Val MSE: 8.428e-08 | Time: 0.29s
# Epochs:  44500 | TrainLoss: 7.496e-05 | Val MSE: 4.275e-07 | Time: 0.29s
# Epochs:  44600 | TrainLoss: 4.233e-05 | Val MSE: 5.209e-08 | Time: 0.29s
# Epochs:  44700 | TrainLoss: 2.898e-05 | Val MSE: 3.906e-08 | Time: 0.29s
# Epochs:  44800 | TrainLoss: 5.974e-05 | Val MSE: 1.696e-07 | Time: 0.29s
# Epochs:  44900 | TrainLoss: 4.195e-05 | Val MSE: 1.305e-06 | Time: 0.30s
# Epochs:  45000 | TrainLoss: 1.831e-04 | Val MSE: 1.158e-06 | Time: 0.29s
# Epochs:  45100 | TrainLoss: 2.985e-04 | Val MSE: 2.654e-06 | Time: 0.29s
# Epochs:  45200 | TrainLoss: 1.008e-04 | Val MSE: 3.519e-07 | Time: 0.29s
# Epochs:  45300 | TrainLoss: 7.395e-05 | Val MSE: 3.836e-07 | Time: 0.29s
# Epochs:  45400 | TrainLoss: 4.086e-05 | Val MSE: 7.810e-08 | Time: 0.29s
# Epochs:  45500 | TrainLoss: 1.611e-04 | Val MSE: 9.244e-07 | Time: 0.30s
# Epochs:  45600 | TrainLoss: 7.286e-05 | Val MSE: 4.254e-07 | Time: 0.32s
# Epochs:  45700 | TrainLoss: 2.872e-05 | Val MSE: 1.550e-08 | Time: 0.32s
# Epochs:  45800 | TrainLoss: 4.129e-05 | Val MSE: 5.305e-08 | Time: 0.30s
# Epochs:  45900 | TrainLoss: 4.938e-05 | Val MSE: 2.947e-08 | Time: 0.29s
# Epochs:  46000 | TrainLoss: 5.937e-05 | Val MSE: 1.687e-07 | Time: 0.29s
# Epochs:  46100 | TrainLoss: 3.024e-05 | Val MSE: 2.405e-08 | Time: 0.29s
# Epochs:  46200 | TrainLoss: 6.773e-05 | Val MSE: 3.797e-07 | Time: 0.30s
# Epochs:  46300 | TrainLoss: 8.758e-05 | Val MSE: 1.256e-07 | Time: 0.29s
# Epochs:  46400 | TrainLoss: 1.617e-03 | Val MSE: 5.820e-06 | Time: 0.29s
# Epochs:  46500 | TrainLoss: 7.125e-05 | Val MSE: 5.930e-07 | Time: 0.29s
# Epochs:  46600 | TrainLoss: 7.499e-04 | Val MSE: 4.989e-06 | Time: 0.29s
# Epochs:  46700 | TrainLoss: 1.523e-04 | Val MSE: 4.134e-07 | Time: 0.29s
# Epochs:  46800 | TrainLoss: 2.592e-05 | Val MSE: 7.582e-09 | Time: 0.30s
# Epochs:  46900 | TrainLoss: 3.167e-05 | Val MSE: 2.038e-08 | Time: 0.29s
# Epochs:  47000 | TrainLoss: 3.799e-05 | Val MSE: 2.245e-07 | Time: 0.29s
# Epochs:  47100 | TrainLoss: 3.760e-05 | Val MSE: 2.777e-08 | Time: 0.29s
# Epochs:  47200 | TrainLoss: 8.993e-04 | Val MSE: 2.591e-07 | Time: 0.29s
# Epochs:  47300 | TrainLoss: 3.919e-03 | Val MSE: 3.018e-05 | Time: 0.29s
# Epochs:  47400 | TrainLoss: 3.249e-05 | Val MSE: 5.078e-08 | Time: 0.29s
# Epochs:  47500 | TrainLoss: 2.737e-05 | Val MSE: 2.787e-08 | Time: 0.29s
# Epochs:  47600 | TrainLoss: 2.663e-05 | Val MSE: 8.081e-09 | Time: 0.29s
# Epochs:  47700 | TrainLoss: 1.050e-03 | Val MSE: 3.223e-06 | Time: 0.30s
# Epochs:  47800 | TrainLoss: 2.413e-04 | Val MSE: 1.308e-07 | Time: 0.29s
# Epochs:  47900 | TrainLoss: 2.500e-05 | Val MSE: 7.438e-09 | Time: 0.30s
# Epochs:  48000 | TrainLoss: 8.610e-05 | Val MSE: 3.433e-07 | Time: 0.29s
# Epochs:  48100 | TrainLoss: 1.929e-03 | Val MSE: 2.033e-06 | Time: 0.29s
# Epochs:  48200 | TrainLoss: 8.032e-05 | Val MSE: 6.114e-07 | Time: 0.29s
# Epochs:  48300 | TrainLoss: 2.516e-05 | Val MSE: 6.919e-09 | Time: 0.29s
# Epochs:  48400 | TrainLoss: 2.899e-05 | Val MSE: 4.552e-08 | Time: 0.29s
# Epochs:  48500 | TrainLoss: 2.552e-05 | Val MSE: 7.775e-09 | Time: 0.29s
# Epochs:  48600 | TrainLoss: 3.089e-05 | Val MSE: 2.038e-08 | Time: 0.29s
# Epochs:  48700 | TrainLoss: 1.610e-04 | Val MSE: 8.185e-07 | Time: 0.30s
# Epochs:  48800 | TrainLoss: 1.868e-04 | Val MSE: 1.943e-06 | Time: 0.29s
# Epochs:  48900 | TrainLoss: 6.972e-05 | Val MSE: 2.428e-08 | Time: 0.29s
# Epochs:  49000 | TrainLoss: 2.103e-03 | Val MSE: 9.736e-06 | Time: 0.29s
# Epochs:  49100 | TrainLoss: 2.397e-03 | Val MSE: 2.028e-05 | Time: 0.29s
# Epochs:  49200 | TrainLoss: 8.548e-03 | Val MSE: 5.498e-05 | Time: 0.29s
# Epochs:  49300 | TrainLoss: 2.467e-05 | Val MSE: 8.624e-09 | Time: 0.31s
# Epochs:  49400 | TrainLoss: 1.915e-04 | Val MSE: 8.612e-08 | Time: 0.32s
# Epochs:  49500 | TrainLoss: 2.459e-04 | Val MSE: 2.064e-07 | Time: 0.31s
# Epochs:  49600 | TrainLoss: 9.654e-04 | Val MSE: 5.735e-06 | Time: 0.31s
# Epochs:  49700 | TrainLoss: 5.775e-05 | Val MSE: 2.502e-07 | Time: 0.31s
# Epochs:  49800 | TrainLoss: 2.450e-05 | Val MSE: 8.760e-09 | Time: 0.36s
# Epochs:  49900 | TrainLoss: 3.864e-05 | Val MSE: 1.187e-07 | Time: 0.29s
# Switching to L-BFGS at epoch 50000 -> starting from Adam best at epoch 49813 (TrainLoss=2.375e-05, Val MSE=7.247e-09)
# Epochs:  50000 | TrainLoss: 2.378e-05 | Val MSE: 6.772e-09 | Time: 0.87s
# Epochs:  50010 | TrainLoss: 2.371e-05 | Val MSE: 6.772e-09 | Time: 0.03s
# Epochs:  50020 | TrainLoss: 2.371e-05 | Val MSE: 6.772e-09 | Time: 0.03s
# Epochs:  50030 | TrainLoss: 2.371e-05 | Val MSE: 6.772e-09 | Time: 0.03s
# Epochs:  50040 | TrainLoss: 2.371e-05 | Val MSE: 6.772e-09 | Time: 0.03s
# Epochs:  50050 | TrainLoss: 2.371e-05 | Val MSE: 6.772e-09 | Time: 0.03s
# Epochs:  50060 | TrainLoss: 2.371e-05 | Val MSE: 6.772e-09 | Time: 0.03s
# Epochs:  50070 | TrainLoss: 2.371e-05 | Val MSE: 6.772e-09 | Time: 0.03s
# Epochs:  50080 | TrainLoss: 2.371e-05 | Val MSE: 6.772e-09 | Time: 0.03s
# Epochs:  50090 | TrainLoss: 2.371e-05 | Val MSE: 6.772e-09 | Time: 0.03s
# Stopping after 100 LBFGS epochs at global epoch 50100
# Total training time: 155.76 s
# Best Val MSE: 6.772e-09 at epoch 50001 (TLoss: 2.371e-05)
# [Summary] Best Val MSE 6.772e-09 at epoch 50001

# %%
# Prepare data
ep_train = range(len(loss_values))

ep_val  = [int(i) for i, _ in mse_v_hist]
mse_val = [ (m.detach().cpu().item() if torch.is_tensor(m) else float(m))
                 for _, m in mse_v_hist ]

plt.figure(figsize=(8, 6))
plt.plot(ep_train, loss_values, color='black', label='Train Loss')
plt.plot(ep_val, mse_val, color='red', label='Validation MSE')
plt.xlabel('Iteration')
plt.ylabel('Loss / MSE')
plt.yscale('log')
plt.title('Training Loss and Validation MSE vs Iterations')
plt.legend()
plt.tight_layout()
plt.show()

# %%
# --- 1) Make the test grid  ---
x_test = np.linspace(x_min, x_max, 100)
t_test = np.linspace(t_min, t_max, 100)
X, T = np.meshgrid(x_test, t_test)            # shapes: (nt, nx)
x_flat = X.flatten()[:, None]                  # (nt*nx, 1)
t_flat = T.flatten()[:, None]                  # (nt*nx, 1)

# --- 2) Build a single input tensor [x, t] on the right device ---
X_star = np.hstack([x_flat, t_flat]).astype(np.float32)  # (N, 2)
X_star_t = torch.from_numpy(X_star).to(device)

# --- 3) Predict with the trained model (no gradients needed) ---
model.eval()
with torch.no_grad():
    u_pred_t = model(X_star_t)                 # (N, 1)

# --- 4) Back to NumPy and reshape to the grid ---
U_pred = u_pred_t.squeeze(1).cpu().numpy().reshape(X.shape)  # (nt, nx)

# --- 5) Plot ---
plt.figure(figsize=(8, 6))
cf = plt.contourf(X, T, U_pred, levels=50, cmap='viridis')
plt.colorbar(cf, label='u(x,t)')
plt.xlabel('x')
plt.ylabel('t')
plt.title("Solution of 1D Heat Equation using PINNs")
plt.tight_layout()
plt.show()

# %%
# Analytical solution on the same grid
U_true = np.exp(-(np.pi**2) * T) * np.sin(np.pi * X)

plt.figure(figsize=(8, 6))
cf = plt.contourf(X, T, U_true, levels=50, cmap='viridis')
plt.colorbar(cf, label='u(x,t)')
plt.xlabel('x'); plt.ylabel('t')
plt.title("Analytical Solution of 1D Heat Equation")
plt.tight_layout(); plt.show()

# %%
# --- Pointwise error for u ---
err_u = np.abs(U_pred - U_true)

plt.figure(figsize=(8, 6))
cf = plt.contourf(X, T, err_u, levels=50, cmap='magma')
plt.colorbar(cf, label='|u_pred - u_true|')
plt.xlabel('x'); plt.ylabel('t'); plt.title('Pointwise Error in u')
plt.tight_layout(); plt.show()

# %%
# Pointwise relative error: |pred - true| / max(|true|, eps)
eps = 1e-12
den = np.maximum(np.abs(U_true), eps)
err_rel = np.abs(U_pred - U_true) / den
err_plot = np.clip(err_rel, eps, None)

vmin, vmax = err_plot.min(), err_plot.max()

# log-spaced levels across powers of 10
lo = np.floor(np.log10(vmin))
hi = np.ceil(np.log10(vmax))
levels = np.logspace(lo, hi, 50)

fig, ax = plt.subplots(figsize=(8, 6))
cf = ax.contourf(X, T, err_plot, levels=levels,
                 norm=LogNorm(vmin=vmin, vmax=vmax), cmap='magma')

# --- Colorbar with custom ticks & formatting ---
cbar = fig.colorbar(cf, ax=ax, label='relative error (log scale)')

# Choose which log ticks you want: only powers of 10, or include 2 & 5 too
# powers of 10 only:
cbar.locator = LogLocator(base=10, subs=(1.0,))        # ticks at 1eN
# or denser: cbar.locator = LogLocator(base=10, subs=(1.0, 2.0, 5.0))

# Scientific formatting (3 digits); e.g., 1.23e-03
cbar.formatter = FuncFormatter(lambda x, pos: f"{x:.1e}")
cbar.update_ticks()

ax.set_xlabel('x'); ax.set_ylabel('t')
ax.set_title('Pointwise Relative Error in u (log color scale)')
fig.tight_layout()
plt.show()

# %%
# --- Symmetry error over the whole (x,t) grid ---
# Mirror across x=0.5 by flipping columns
U_mirror = U_pred[:, ::-1]                 # same shape as U_pred
E_sym = U_pred - U_mirror                  # antisymmetric part
AbsE = np.abs(E_sym)                       # magnitude of asymmetry

plt.figure(figsize=(8, 6))
cf = plt.contourf(X, T, AbsE, levels=50, cmap='magma')
plt.colorbar(cf, label='|U(x,t) - U(1-x,t)|')
plt.xlabel('x'); plt.ylabel('t')
plt.title('Symmetry Error Magnitude |U(x,t) - U(1-x,t)|')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 6))
levels = np.linspace(0.0, 0.001, 51)  # 0 → 0.002
cf = plt.contourf(X, T, AbsE, levels=levels, cmap='magma', vmin=0.0, vmax=0.001)
cbar = plt.colorbar(cf, label='|U(x,t) - U(1-x,t)|')
cbar.set_ticks([0.0000, 0.0001, 0.0002, 0.0003, 0.0004, 0.0005, 0.0006, 0.0007, 0.0008, 0.0009, 0.0010])
cbar.ax.yaxis.set_major_formatter(FormatStrFormatter('%.4f'))

plt.xlabel('x'); plt.ylabel('t')
plt.title('Symmetry Error Magnitude |U(x,t) - U(1-x,t)|')
plt.tight_layout()
plt.show()

# %%
# sMAPE: |pred - true| / ( (|pred| + |true|)/2 + eps )
eps = 1e-12
err_smapE = np.abs(U_pred - U_true) / (0.5*(np.abs(U_pred) + np.abs(U_true)) + eps)

plt.figure(figsize=(8, 6))
cf = plt.contourf(X, T, err_smapE, levels=50, cmap='magma')
plt.colorbar(cf, label='symmetric relative error')
plt.xlabel('x'); plt.ylabel('t'); plt.title('Pointwise sMAPE in u')
plt.tight_layout(); plt.show()

# %%
num = np.linalg.norm(U_pred - U_true)
den = np.linalg.norm(U_true)
rel_L2 = num / den if den > 0 else num  # if all-zeros true, fall back to absolute norm
print(f"Global relative L2 error: {rel_L2:.3e}")
# Out:
# Global relative L2 error: 2.552e-04

# %% [markdown]
# <div style="padding: 10px;">
#
# # Use trained model to predict from data sample
#
# The function `evaluate` will evaluate the solution `u` on a given grid using the trained model
#
# </div>

# %%
def evaluate(model, x_star, t_star):
    """
    Evaluate the solution u and the residual f of the 1D heat equation using the trained PINN model.

    Parameters:
    model (torch.nn.Module): The trained Physics-Informed Neural Network model.
    x_star (numpy.ndarray): Array of spatial points where predictions are to be made.
    t_star (numpy.ndarray): Array of temporal points where predictions are to be made.

    Returns:
    tuple: A tuple containing:
        - u_star (numpy.ndarray): Predicted solution at the given spatial and temporal points.
        - f_star (numpy.ndarray): Predicted residual of the PDE at the given spatial and temporal points.
    """

    # 1) Use the model's device
    dev = next(model.parameters()).device

    # Convert input spatial points to a PyTorch tensor with gradient tracking enabled
    x_star_tf = torch.tensor(x_star, dtype=torch.float32, device=dev, requires_grad=True)
    # Convert input temporal points to a PyTorch tensor with gradient tracking enabled
    t_star_tf = torch.tensor(t_star, dtype=torch.float32, device=dev, requires_grad=True)
    # Evaluate the solution u using the model
    u_star = net_u(x_star_tf, t_star_tf, model)
    # Evaluate the residual f of the PDE using the model
    f_star = net_f(x_star_tf, t_star_tf, model)

    # Detach the Evaluations from the computation graph and convert to NumPy arrays
    return u_star.detach().cpu().numpy(), f_star.detach().cpu().numpy()

# %%
# u_eval, f_eval = evaluate(model,X_star[:,0:1],X_star[:,1:2])

# u_pred = net_u(x_tf, t_tf, model )
# f_pred = net_f(x_f_t, t_f_t, model)

# error_u = np.linalg.norm(u_star-u_eval,2)/np.linalg.norm(u_star,2)

# %% [markdown]
# <div style="padding: 10px;">
#
# # Diagnostics: Errors
#
# </div>

# %%
# print("Mean of physics residual = ", np.mean(f_eval))
# print('Percent error in solution: ',  100*error_u)

# %% [markdown]
# <div style="padding: 10px;">
#
# # Plots of original, reconstructed solutions $u(x,t)$ and their difference
#
#
#
# </div>

# %%
# # Set grid values back to full data set size for plotting

# t = data['t'].flatten()[:,None]
# x = data['x'].flatten()[:,None]
# X, T = np.meshgrid(x,t)

# U_pred = u_eval.reshape(Exact.shape)
# Error = np.abs(Exact - U_pred)
# percentError = 100*np.divide(Error, Exact)


# fig, ax = plt.subplots(figsize=(15,15))
# ax.axis('off')

# t = data['t'].flatten()[:,None]
# x = data['x'].flatten()[:,None]
# X, T = np.meshgrid(x,t)

# U_pred = u_eval.reshape(Exact.shape)
# Error = np.abs(Exact - U_pred)
# percentError = 100*np.divide(Error, Exact)


# ####### Row 0: u(t,x) ##################
# gs0 = gridspec.GridSpec(3, 1)
# gs0.update(top=1-0.06, bottom=1-1/3, left=0.15, right=0.85, wspace=0, hspace=1)


# ########## Prediction ##################
# ax = plt.subplot(gs0[0, :])
# h = ax.imshow(U_pred.T, interpolation='nearest', cmap='rainbow',
#               extent=[t.min(), t.max(), x.min(), x.max()],
#               origin='lower', aspect='auto', vmin = 0, vmax = 1)
# divider = make_axes_locatable(ax)
# cax = divider.append_axes("right", size="5%", pad=0.05)
# fig.colorbar(h, cax=cax)

# ax.plot(X_u_train[:,1], X_u_train[:,0], 'kx', label = 'Data (%d points)' % (u_train.shape[0]), markersize = 4, clip_on = False)

# line = np.linspace(x.min(), x.max(), 2)[:,None]
# ax.plot(t[2]*np.ones((2,1)), line, 'w-', linewidth = 1)
# ax.plot(t[5]*np.ones((2,1)), line, 'w-', linewidth = 1)
# ax.plot(t[10]*np.ones((2,1)), line, 'w-', linewidth = 1)

# ax.set_xlabel('$t$')
# ax.set_ylabel('$x$')
# ax.legend(frameon=False, loc = 'best')
# ax.set_title('$u(t,x) - Prediction$', fontsize = 10)

# ########## Exact ##################
# ax = plt.subplot(gs0[1, :])
# i = ax.imshow(Exact.T, interpolation='nearest', cmap='rainbow',
#               extent=[t.min(), t.max(), x.min(), x.max()],
#               origin='lower', aspect='auto', vmin = 0, vmax = 1)
# divider = make_axes_locatable(ax)
# cax = divider.append_axes("right", size="5%", pad=0.05)
# fig.colorbar(i, cax=cax)

# ax.plot(X_u_train[:,1], X_u_train[:,0], 'kx', label = 'Data (%d points)' % (u_train.shape[0]), markersize = 4, clip_on = False)

# line = np.linspace(x.min(), x.max(), 2)[:,None]
# ax.plot(t[2]*np.ones((2,1)), line, 'w-', linewidth = 1)
# ax.plot(t[5]*np.ones((2,1)), line, 'w-', linewidth = 1)
# ax.plot(t[10]*np.ones((2,1)), line, 'w-', linewidth = 1)

# ax.set_xlabel('$t$')
# ax.set_ylabel('$x$')
# ax.legend(frameon=False, loc = 'best')
# ax.set_title('$u(t,x)$ - Exact', fontsize = 10)

# ########## Error ##################
# ax = plt.subplot(gs0[2, :])
# j = ax.imshow(percentError.T, interpolation='nearest', cmap='rainbow',
#               extent=[t.min(), t.max(), x.min(), x.max()],
#               origin='lower', aspect='auto', vmin = 0, vmax = 10)
# divider = make_axes_locatable(ax)
# cax = divider.append_axes("right", size="5%", pad=0.05)
# fig.colorbar(j, cax=cax)

# ax.plot(X_u_train[:,1], X_u_train[:,0], 'kx', label = 'Data (%d points)' % (u_train.shape[0]), markersize = 4, clip_on = False)

# line = np.linspace(x.min(), x.max(), 2)[:,None]
# ax.plot(t[2]*np.ones((2,1)), line, 'w-', linewidth = 1)
# ax.plot(t[5]*np.ones((2,1)), line, 'w-', linewidth = 1)
# ax.plot(t[10]*np.ones((2,1)), line, 'w-', linewidth = 1)

# ax.set_xlabel('$t$')
# ax.set_ylabel('$x$')
# ax.legend(frameon=False, loc = 'best')
# ax.set_title('$u(t,x)$ - Percent difference', fontsize = 10)


# ####### Row 1: u(t,x) slices ##################

# fig, ax = plt.subplots(figsize=(15,5))
# ax.axis('off')
# gs1 = gridspec.GridSpec(1, 3)
# gs1.update(top=1-1/3, bottom=0, left=0.1, right=0.9, wspace=0.5)

# ax = plt.subplot(gs1[:, 0])
# ax.plot(x,Exact[2,:], 'b-', linewidth = 2, label = 'Exact')
# ax.plot(x,U_pred[2,:], 'r--', linewidth = 2, label = 'Prediction')
# ax.set_xlabel('$x$')
# ax.set_ylabel('$u(t,x)$')
# ax.set_title('$t = ' + str(t[2,0]) + '$', fontsize = 10)
# ax.axis('square')
# ax.set_xlim([0,1])
# ax.set_ylim([0,1])

# ax = plt.subplot(gs1[:, 1])
# ax.plot(x,Exact[5,:], 'b-', linewidth = 2, label = 'Exact')
# ax.plot(x,U_pred[5,:], 'r--', linewidth = 2, label = 'Prediction')
# ax.set_xlabel('$x$')
# ax.set_ylabel('$u(t,x)$')
# ax.axis('square')
# ax.set_xlim([0,1])
# ax.set_ylim([0,1])
# ax.set_title('$t = ' + str(t[5,0]) + '$', fontsize = 10)
# ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.35), ncol=5, frameon=False)

# ax = plt.subplot(gs1[:, 2])
# ax.plot(x,Exact[10,:], 'b-', linewidth = 2, label = 'Exact')
# ax.plot(x,U_pred[10,:], 'r--', linewidth = 2, label = 'Prediction')
# ax.set_xlabel('$x$')
# ax.set_ylabel('$u(t,x)$')
# ax.axis('square')
# ax.set_xlim([0,1])
# ax.set_ylim([0,1])
# ax.set_title('$t = ' + str(t[10,0]) + '$', fontsize = 10);

# %% [markdown]
# <div style="padding: 10px;">
#
# ## Summary of results
#
# The relative error for recreating the full solution is at most $\approx 5 \%$ (and mostly much smaller), despite using only $N_u = 100$ data points. This shows the power of PINNs to learn from sparse measurements by augmenting the available observational data with knowledge of the underlying physics (i.e. governing equations).
#
# We can see that the errors are largest near $t=0$ and $x=0$, but that overall the agreement is very good.
#
# On the colourmap, we can see three vertical white lines, which show the location in time of the three profile plots of $u$ against $x$. The three heat profiles at these times are plotted against the exact solution found using numerical methods. The profiles can be seen to be in very good agreement.
#
# **Further Work**
#
# Congratulations, you have now trained your first physics-informed neural network!
#
# This network contains a number of hyper-parameters that could be tuned to give better results. Various hyper-parameters include:
# - number of data training points N_u
# - number of collocation training points N_f
# - number of layers in the network
# - number of neurons per layer
# - weightings for the data and PDE loss terms in the loss function (currently we use loss = loss_PDE + 5*loss_data)
#
# It is also possible to use different sampling techniques for training data points. We randomly select $N_u$ data points, but alternative methods could be choosing only boundary points or choosing more points near the $t=0$ boundary. Choosing boundary points for training could help to reduce the errors seen in these regions.
#
# Feel free to try out some of these changes if you like!
#
# </div>

# %%
lb = np.array([0.0, 0.0], dtype=np.float32)
ub = np.array([1.0, 0.25], dtype=np.float32)
U = lhs(2, samples=5)   # shape (N_f, 2)
X_f_train = lb + (ub-lb) * U # the 2 denotes the number of coordinates we have - x,t
print(lb)
print(ub)
print(U)
print(X_f_train)
# Out:
# [0. 0.]
# [1.   0.25]
# [[0.28904131 0.60257362]
#  [0.52898297 0.26395289]
#  [0.16779642 0.94047439]
#  [0.87554406 0.12498546]
#  [0.75652077 0.43972801]]
# [[0.28904131 0.1506434 ]
#  [0.52898297 0.06598822]
#  [0.16779642 0.2351186 ]
#  [0.87554406 0.03124637]
#  [0.75652077 0.109932  ]]
